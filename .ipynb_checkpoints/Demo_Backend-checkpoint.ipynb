# %%
from bs4 import BeautifulSoup
import os
import requests
import urllib.request as urllib2
import re
import googlemaps as gmap
import json
from geopy.geocoders import Nominatim
import gensim
#importing the model
nlp_model = gensim.models.KeyedVectors.load_word2vec_format('/Users/joshuadarcy/Desktop/GoogleNews-vectors-negative300.bin', binary = True)

# %%
class google_api_search(object):

    def search_parse(self, lat, lng):
        location = (lat, lng)
        # Query google places api
        goog = gmap.Client(key=self.api_key)
        geocode_result = goog.places(query=self.query, location=location, radius=self.radius, type = 'restuarant')

        goog.places
        # Collect results
        results = geocode_result['results']

        # Clean JSON and create list
        geo_list = []
        for result in results:
            name = result['name'].lower()
            latitude = result['geometry']['location']['lat']
            longitude = result['geometry']['location']['lng']
            geo_list.append((name, (latitude, longitude)))

        return geo_list

    def __init__(self, query='restaurant', radius=1000):
        # set parameters
        self.radius = radius
        self.api_key = 'AIzaSyDzs7Yezb7ZUCCajqPY0yjRR4LBUkA2Ugw'
        self.query = query
        # run search parse and create an instance variable called geo_list that you can reference
        # self.geo_list = self.search_parse(35.9940, -78.8986)

def sort_header(bea_soup): 
    all_headers = bea_soup.find_all('h1')
    for header in all_headers: 
        text = header.get_text()
        if 'Grub' in text:
            continue
        else: 
            return text

# %%
def collect_durham(rad,lat,long):

    # testing difference radii, questions about how to get more restaurants
    set1 = set(google_api_search(query='restaurant|food', radius=rad).search_parse(lat, long))

    # find the union of all the sets (a set will inherently get rid of multiples)
    source_list = set1

    # split the geo_list into two separate arrays, one for purely names and one for locations
    names, locations = zip(*source_list)
    map_locations = dict(zip(names, locations))

    # WEB SCRAPING

    # starting link for allmenus, call BeautifulSoup
    URL_base = "https://www.allmenus.com/nc/durham/-/"
    page = urllib2.urlopen(URL_base)
    soup = BeautifulSoup(page, "html.parser")
    all_possible_links = soup.findAll("a", {"data-masterlist-id": re.compile(r".*")})

    # all the correct, cleaned links gotten from BeautifulSoup
    links = []

    # list of restaurant names obtained from the links
    master_list = []

    # FINAL list of restaurants used found based on the intersection of master_list and names from above
    links_used = []
    locations_used = []
    names_used = []

    # the list of restaurants that overlap with google places, hard-coded currently WILL HAVE TO FIND MORE EFFICIENT METHOD

    # used to traverse all the possibilities on allmenus and find out what matches google places results
    for link in all_possible_links:
        if link.has_attr('href'):
            raw_href = link.attrs['href']
            wanted_href = raw_href.replace("/nc/durham/", "")
            turn_string = str(wanted_href)
            find = str(re.search("(?<=-).*", turn_string).group())
            find = find.replace('/menu/', '')
            find = find.replace('-', ' ')
            find = find.replace(' s', '\'s')
            master_list.append(find)
            links.append(wanted_href)

            if find in names:
                links_used.append(wanted_href)
                locations_used.append(map_locations.get(find))
                names_used.append(find)

    # find the intersection of the lists
    master_list_set = set(master_list)
    final_list = master_list_set.intersection(names)

    URL_base2 = "https://www.allmenus.com/nc/durham/"

    # where all the data is stored for the JSON
    restaurants = []

    for id, location_goog in zip(links_used, locations_used):
        URL = URL_base2 + id
        r = requests.get(URL)
        bsObj = BeautifulSoup(r.content, 'html.parser')

        #Function to parse out any mention of Grubhub
        restaurant = sort_header(bsObj)
        
        #Check for chains, skip if chain present
        if any (restp['Name'] == restaurant for restp in restaurants):
            continue
            
        location = location_goog
        name = restaurant
        titles = bsObj.find_all("span", attrs={'class': 'item-title'})
        ingredients = bsObj.find_all("p", attrs={'class': 'description'})

        prices = bsObj.find_all("span", attrs={'class': 'item-price'})


        # where all the menu items are held with the format above
        # use regex to clean up the ingredients, will have to continue adding to this dictionary
        
        remove = {',': '', '.': '', ':':''}
        pattern = '|'.join(sorted(re.escape(k) for k in remove))

        #cleaning/processing of ingredients by menu item
        #create array of menu items

        menu = []
        for item, price, ingredient in zip(titles, prices, ingredients):

            menu_item = {
            "item": "",
            "price": "",
            "ingredients": []
            }

            #menu name
            menu_item["item"] = item.get_text()
            
            #menu price
            stripped_price = price.get_text()
            stripped_price = stripped_price.strip(' \t\n')
            menu_item["price"] = stripped_price
            clean_ingredient = str(ingredient.get_text())


            clean_ingredient = re.sub(pattern, lambda m: remove.get(m.group(0).upper()), clean_ingredient, flags=re.IGNORECASE)
            current_ingredient = re.split("[\s,\&]", clean_ingredient)

            if len(current_ingredient) == 1:
                current_ingredient = re.split("[\s,\&]", menu_item["item"])
    #             current_ingredient[0] = menu_item["item"]

            final_ingredient = []
        
            #NLP to find food
            for word in current_ingredient:
                try:
                    if nlp_model.similarity('edible', word) > .1 and nlp_model.similarity('food', word) > .15:
                        final_ingredient.append(word)
                except: 
                    continue

            menu_item['ingredients'] = final_ingredient

            menu.append(menu_item)

        data = {
            "Name": name,
            "Location": location,
            "Menu": menu
        }
        restaurants.append(data)
        
    return restaurants

# %% [markdown]
# ### Nutritional Value Demo

# %%
rest = collect_durham(10000, 36.008387, -78.943826)
recommended_dictionary = recommended_dict(gender = 1, activity = 0, age = 25)
rest[0]['Menu'][0].keys()
# Out:
# dict_keys(['item', 'price', 'ingredients'])

# %%
shrimp = rest[0]['Menu'][0]

# %%
menu_item = single_dictionary(shrimp)
menu_item
# Out:
# ---------------------------------------------------------------------------
# DataGovApiRateExceededError               Traceback (most recent call last)
# <ipython-input-5-182841c463e6> in single_dictionary(menu_item)
#       6         try:
# ----> 7             menu_item['nutrition'][ingredient] = nutri_search(ingredient)
#       8         except:
#
# <ipython-input-6-79dd7ad63177> in nutri_search(ingredient)
#       6     foods_search = client.search_foods('{}'.format(ingredient), 1)
# ----> 7     food = next(foods_search)
#       8
#
# /usr/local/lib/python3.7/site-packages/usda/pagination.py in __next__(self)
#     173     def __next__(self):
# --> 174         return self.model.from_response_data(next(self.raw))
#
# /usr/local/lib/python3.7/site-packages/usda/pagination.py in __next__(self)
#      87                 raise StopIteration
# ---> 88             self._fetch_next()
#      89         return self.data[self.itemkey].pop(0)
#
# /usr/local/lib/python3.7/site-packages/usda/pagination.py in _fetch_next(self)
#      93         self.data = self.client.run_request(
# ---> 94             *self.request_args, **self.request_kwargs)[self.listkey]
#      95         self.current_offset += self.max
#
# /usr/local/lib/python3.7/site-packages/usda/base.py in run_request(self, uri_action, **kwargs)
#     116             kwargs['format'] = 'json'
# --> 117         return api_request(self.build_uri(uri_action), **kwargs)
#
# /usr/local/lib/python3.7/site-packages/usda/base.py in api_request(url, **parameters)
#      68     elif err['code'] == "OVER_RATE_LIMIT":
# ---> 69         raise DataGovApiRateExceededError()
#      70     elif err['code'] == "API_KEY_INVALID":
#
# DataGovApiRateExceededError: API rate limit has been exceeded.
#
# During handling of the above exception, another exception occurred:
#
# DataGovApiRateExceededError               Traceback (most recent call last)
# <ipython-input-11-44322ad6e31e> in <module>
# ----> 1 menu_item = single_dictionary(shrimp)
#       2 menu_item
#
# <ipython-input-5-182841c463e6> in single_dictionary(menu_item)
#       7             menu_item['nutrition'][ingredient] = nutri_search(ingredient)
#       8         except:
# ----> 9             print(nutri_search(ingredient))
#      10             continue
#      11     return menu_item
#
# <ipython-input-6-79dd7ad63177> in nutri_search(ingredient)
#       5     #find ID number
#       6     foods_search = client.search_foods('{}'.format(ingredient), 1)
# ----> 7     food = next(foods_search)
#       8
#       9     report = client.get_food_report(food.id)
#
# /usr/local/lib/python3.7/site-packages/usda/pagination.py in __next__(self)
#     172
#     173     def __next__(self):
# --> 174         return self.model.from_response_data(next(self.raw))
#
# /usr/local/lib/python3.7/site-packages/usda/pagination.py in __next__(self)
#      86                     self.current_offset >= self.data['end']:
#      87                 raise StopIteration
# ---> 88             self._fetch_next()
#      89         return self.data[self.itemkey].pop(0)
#      90
#
# /usr/local/lib/python3.7/site-packages/usda/pagination.py in _fetch_next(self)
#      92         self.request_kwargs['offset'] = self.current_offset
#      93         self.data = self.client.run_request(
# ---> 94             *self.request_args, **self.request_kwargs)[self.listkey]
#      95         self.current_offset += self.max
#      96
#
# /usr/local/lib/python3.7/site-packages/usda/base.py in run_request(self, uri_action, **kwargs)
#     115         if 'format' not in kwargs and self.use_format:
#     116             kwargs['format'] = 'json'
# --> 117         return api_request(self.build_uri(uri_action), **kwargs)
#
# /usr/local/lib/python3.7/site-packages/usda/base.py in api_request(url, **parameters)
#      67                 err['parameter'], err['message']))
#      68     elif err['code'] == "OVER_RATE_LIMIT":
# ---> 69         raise DataGovApiRateExceededError()
#      70     elif err['code'] == "API_KEY_INVALID":
#      71         raise DataGovInvalidApiKeyError()
#
# DataGovApiRateExceededError: API rate limit has been exceeded.

# %%
restaurants = rest

# %% [markdown]
# ### Score the Meal

# %%
nutrientScore(menu_item['nutrition'], recommended_dictionary)
# Out:
# -8

# %%
def score_local_meals_per_user(radius,lat,long,gender,activity,age): 
    #Collect options in the area.
    restaurants = collect_durham(radius,lat,long)
    print("Restaurants Collected.")
    #Add in nutritional values for each item in dictionary
    
    for restaurant in restaurants:
        menu = restaurant['Menu']
        counter = 0
        for item in menu: 
            menu[counter] = single_dictionary(item)
            counter +=1
        return restaurants
        
    print("Nutritional Information Obtained.")   
    #Optimal recommended dictionary construction, will need to move this outside function in future
    recommended_dictionary = recommended_dict(gender = gender, activity = activity, age = age)
    
    return restaurants

# %%
score_meals_per_user(500,36.008387, -78.943826,1,0,25)
# Out:
# Restaurants Collected.
# [{'Name': 'Parizade',
#   'Location': (36.0080117, -78.9265703),
#   'Menu': [{'item': 'Grilled Shrimp Plate',
#     'price': '$7.00',
#     'ingredients': ['Watermelon', 'raita'],
#     'nutrition': {}},
#    {'item': 'Antipasto Skewers Plate',
#     'price': '$6.00',
#     'ingredients': ['Salami',
#      'pepperoncini',
#      'olives',
#      'heirloom',
#      'tomatoes'],
#     'nutrition': {}},
#    {'item': 'Organic Green Chickpea Hummus',
#     'price': '$9.00',
#     'ingredients': ['garlic'],
#     'nutrition': {}},
#    {'item': 'Tomato Harissa',
#     'price': '$8.00',
#     'ingredients': ['fenugreek'],
#     'nutrition': {}},
#    {'item': 'Spicy Red Pepper & Feta',
#     'price': '$9.00',
#     'ingredients': ['garlic', 'nuts'],
#     'nutrition': {}},
#    {'item': 'Tzatziki',
#     'price': '$9.00',
#     'ingredients': ['Greek', 'yogurt', 'cucumber', 'dill'],
#     'nutrition': {}},
#    {'item': 'Mezze Trio',
#     'price': '$22.00',
#     'ingredients': ['tzatziki', 'spicy', 'feta', 'chickpea', 'hummus'],
#     'nutrition': {}},
#    {'item': 'Soup du Jour',
#     'price': '$7.00',
#     'ingredients': ['Soup'],
#     'nutrition': {}},
#    {'item': 'Bruschetta',
#     'price': '$6.00',
#     'ingredients': ['Tomato', 'tapenade', 'basil', 'feta'],
#     'nutrition': {}},
#    {'item': 'Fried Calamari',
#     'price': '$8.00',
#     'ingredients': ['pepperoncini', 'aioli'],
#     'nutrition': {}},
#    {'item': 'Tuna Tartar',
#     'price': '$14.00',
#     'ingredients': ['Pickled', 'fennel', 'coriander', 'seeds', 'almonds'],
#     'nutrition': {}},
#    {'item': 'Marinated Olives',
#     'price': '$5.00',
#     'ingredients': ['Thyme', 'citrus', 'garlic', 'chili'],
#     'nutrition': {}},
#    {'item': 'Arancini',
#     'price': '$5.00',
#     'ingredients': ['Goat', 'cheese', 'tomato', 'pesto', 'aioli'],
#     'nutrition': {}},
#    {'item': 'Seafood Cassoulet',
#     'price': '$14.00',
#     'ingredients': ['Shrimp', 'scallops', 'squid', 'bread', 'rouille'],
#     'nutrition': {}},
#    {'item': 'Roasted Baby Beets',
#     'price': '$8.00',
#     'ingredients': ['Goat', 'cheese', 'radish', 'pistachios'],
#     'nutrition': {}},
#    {'item': 'Arancini',
#     'price': '$5.00',
#     'ingredients': ['goat', 'aioli'],
#     'nutrition': {}},
#    {'item': 'Crispy Eggplant',
#     'price': '$9.00',
#     'ingredients': ['ricotta', 'basil', 'aioli'],
#     'nutrition': {}},
#    {'item': 'Fried Calamari',
#     'price': '$8.00',
#     'ingredients': ['aioli'],
#     'nutrition': {}},
#    {'item': 'Grilled Octopus',
#     'price': '$14.00',
#     'ingredients': ['potatoes', 'olives', 'wine', 'vinaigrette'],
#     'nutrition': {}},
#    {'item': 'Heirloom Tomatoes',
#     'price': '$8.00',
#     'ingredients': ['Pickled', 'basil', 'water'],
#     'nutrition': {}},
#    {'item': 'Roasted Octopus',
#     'price': '$14.00',
#     'ingredients': ['sauce', 'salsa', 'criolla'],
#     'nutrition': {}},
#    {'item': 'Smoked Salmon',
#     'price': '$11.00',
#     'ingredients': ['marinade', 'almonds', 'lavash'],
#     'nutrition': {}},
#    {'item': 'Soup de Jour',
#     'price': '$7.00',
#     'ingredients': ['restaurant'],
#     'nutrition': {}},
#    {'item': 'Steamed Mussels & Clams',
#     'price': '$10.00',
#     'ingredients': ['garlic', 'croutons', 'lobster', 'butter', 'aioli'],
#     'nutrition': {}},
#    {'item': 'Fried Brussels Sprouts',
#     'price': '$8.00',
#     'ingredients': ['Walnuts', 'Parmesan', 'vinaigrette'],
#     'nutrition': {}},
#    {'item': 'Braised Octopus',
#     'price': '$14.00',
#     'ingredients': ['Potato', 'gnocchi', 'tomatoes', 'parsley'],
#     'nutrition': {}},
#    {'item': 'Grilled Shrimp Saganaki',
#     'price': '$8.00',
#     'ingredients': ['roasted', 'tomato', 'feta', 'dill'],
#     'nutrition': {}},
#    {'item': 'Greek Chicken Avgolemono',
#     'price': '$6.00',
#     'ingredients': ['spinach', 'orzo', 'bowl'],
#     'nutrition': {}},
#    {'item': 'Tomato Crostini',
#     'price': '$12.00',
#     'ingredients': ['tapenade', 'feta', 'basil'],
#     'nutrition': {}},
#    {'item': 'Fried or Grilled Calamari',
#     'price': '$7.00',
#     'ingredients': ['arugula', 'tomato', 'oregano'],
#     'nutrition': {}},
#    {'item': 'Goat Cheese Herb Toast',
#     'price': '$6.00',
#     'ingredients': ['grilled', 'vegetables'],
#     'nutrition': {}},
#    {'item': 'Burrata',
#     'price': '$13.00',
#     'ingredients': ['prosciutto', 'arugula', 'bread', 'tomato'],
#     'nutrition': {}},
#    {'item': 'Watermelon & Feta',
#     'price': '$12.00',
#     'ingredients': ['water',
#      'melon',
#      'feta',
#      'roasted',
#      'grapes',
#      'almond',
#      'dukkah',
#      'basil'],
#     'nutrition': {}},
#    {'item': 'Smoked Trout',
#     'price': '$10.00',
#     'ingredients': ['tzatziki', 'onion', 'cucumber', 'dill', 'pita', 'bread'],
#     'nutrition': {}},
#    {'item': 'Marinated Olives',
#     'price': '$6.00',
#     'ingredients': ['citrus', 'chili'],
#     'nutrition': {}},
#    {'item': 'Roasted Mushrooms',
#     'price': '$12.00',
#     'ingredients': ['garlic', 'polenta', 'parmesan', 'cheese', 'fried'],
#     'nutrition': {}},
#    {'item': "Caramelized Sheep's Milk Cheese",
#     'price': '$12.00',
#     'ingredients': ['dried', 'cranberry', 'chutney'],
#     'nutrition': {}},
#    {'item': 'Lamb Keftedes',
#     'price': '$13.00',
#     'ingredients': ['yogurt', 'Greek', 'slaw'],
#     'nutrition': {}},
#    {'item': 'Bacalao Fritters',
#     'price': '$10.00',
#     'ingredients': ['sofrito'],
#     'nutrition': {}},
#    {'item': 'Grilled Portuguese Octopus',
#     'price': '$18.00',
#     'ingredients': ['chickpeas', 'chorizo', 'radish'],
#     'nutrition': {}},
#    {'item': 'Baked Halloumi Cheese',
#     'price': '$11.00',
#     'ingredients': ['tomato', 'olive', 'chili'],
#     'nutrition': {}},
#    {'item': 'Baked Shrimp',
#     'price': '$14.00',
#     'ingredients': ['tomatoes', 'feta', 'chilies', 'Greek', 'oregano'],
#     'nutrition': {}},
#    {'item': 'Blistered Shishito Peppers',
#     'price': '$11.00',
#     'ingredients': ['Romesco', 'Greek', 'yogurt'],
#     'nutrition': {}},
#    {'item': 'Parizade Salad',
#     'price': '$10.00',
#     'ingredients': ['greens', 'strawberries', 'cheese', 'vinaigrette'],
#     'nutrition': {}},
#    {'item': 'Greek Country Salad',
#     'price': '$12.00',
#     'ingredients': ['Tomatoes',
#      'cucumber',
#      'peppers',
#      'onions',
#      'olives',
#      'feta',
#      'wine',
#      'vinaigrette'],
#     'nutrition': {}},
#    {'item': 'Caesar Salad',
#     'price': '$8.00',
#     'ingredients': ['Garlic', 'croutons', 'Parmesan'],
#     'nutrition': {}},
#    {'item': 'Caprese Salad',
#     'price': '$9.00',
#     'ingredients': ['Tomato', 'fresh', 'mozzarella', 'basil'],
#     'nutrition': {}},
#    {'item': 'Poached Pear and Endive Salad',
#     'price': '$9.00',
#     'ingredients': ['Grapes',
#      'walnuts',
#      'cheese',
#      'apple',
#      'cider',
#      'vinaigrette'],
#     'nutrition': {}},
#    {'item': 'Spicy Greens',
#     'price': '$10.00',
#     'ingredients': ['goat', 'cheese', 'prosciutto', 'grapes'],
#     'nutrition': {}},
#    {'item': 'Tuscan Kale',
#     'price': '$9.00',
#     'ingredients': ['roasted',
#      'beets',
#      'nuts',
#      'chili',
#      'feta',
#      'vinaigrette'],
#     'nutrition': {}},
#    {'item': 'Baby Organic Kale',
#     'price': '$12.00',
#     'ingredients': ['nuts',
#      'dried',
#      'cranberry',
#      'goat',
#      'cheese',
#      'cider',
#      'vinegar'],
#     'nutrition': {}},
#    {'item': 'Marouli',
#     'price': '$12.00',
#     'ingredients': ['baby', 'romaine', 'fennel', 'cheese', 'dill'],
#     'nutrition': {}},
#    {'item': 'Horiatiki',
#     'price': '$14.00',
#     'ingredients': ['organic',
#      'hot',
#      'tomatoes',
#      'feta',
#      'peppers',
#      'cucumber',
#      'onions',
#      'oregano',
#      'Greek',
#      'vinegar',
#      'olive',
#      'oil'],
#     'nutrition': {}},
#    {'item': 'Caesar',
#     'price': '$12.00',
#     'ingredients': ['anchovy', 'Reggiano', 'parm', 'sourdough', 'toast'],
#     'nutrition': {}},
#    {'item': 'Iceberg Wedge',
#     'price': '$12.00',
#     'ingredients': ['feta',
#      'dressing',
#      'tomatoes',
#      'onion',
#      'pepperoncini',
#      'chorizo'],
#     'nutrition': {}},
#    {'item': 'Lemon Tagliatelle',
#     'price': '$20.00',
#     'ingredients': ['seasonal', 'vegetables', 'pesto', 'cheese'],
#     'nutrition': {}},
#    {'item': 'Organic Grain Pilaf',
#     'price': '$18.00',
#     'ingredients': ['farro',
#      'quinoa',
#      'mushrooms',
#      'greens',
#      'almonds',
#      'vinaigrette'],
#     'nutrition': {}},
#    {'item': 'Agnolotti',
#     'price': '$22.00',
#     'ingredients': ['ricotta', 'shiitake', 'mushrooms', 'brodo'],
#     'nutrition': {}},
#    {'item': 'Angel Hair',
#     'price': '$25.00',
#     'ingredients': ['shrimp', 'tomato', 'feta'],
#     'nutrition': {}},
#    {'item': 'Cavatelli',
#     'price': '$22.00',
#     'ingredients': ['duck', 'bacon', 'bolognese', 'ricotta'],
#     'nutrition': {}},
#    {'item': 'Angel Hair Shrimp',
#     'price': '$18.00',
#     'ingredients': ['tomatoes', 'feta', 'basil'],
#     'nutrition': {}},
#    {'item': 'Bucatini Bolognese',
#     'price': '$20.00',
#     'ingredients': ['meat', 'sauce'],
#     'nutrition': {}},
#    {'item': 'Lemon Linguini',
#     'price': '$17.00',
#     'ingredients': ['Spinach',
#      'zucchini',
#      'mushrooms',
#      'peppers',
#      'tomatoes',
#      'pesto',
#      'feta'],
#     'nutrition': {}},
#    {'item': 'Lemon Linguini',
#     'price': '$17.00',
#     'ingredients': ['Zucchini',
#      'spinach',
#      'mushrooms',
#      'peppers',
#      'tomatoes',
#      'pesto',
#      'feta'],
#     'nutrition': {}},
#    {'item': 'Mushroom and Butternut Squash Risotto',
#     'price': '$18.00',
#     'ingredients': ['butter', 'pumpkin', 'seeds', 'ricotta', 'salata'],
#     'nutrition': {}},
#    {'item': 'Seafood Risotto Provencal',
#     'price': '$23.00',
#     'ingredients': ['Shrimp', 'scallops', 'basil', 'tomatoes'],
#     'nutrition': {}},
#    {'item': 'Baked Gnocchi',
#     'price': '$18.00',
#     'ingredients': ['tomato', 'fresh', 'mozzarella', 'basil'],
#     'nutrition': {}},
#    {'item': 'Squid Ink Paella',
#     'price': '$30.00',
#     'ingredients': ['shrimp', 'scallops', 'aioli'],
#     'nutrition': {}},
#    {'item': 'Seared Scallops',
#     'price': '$26.00',
#     'ingredients': ['Cauliflower', 'romesco', 'chutney'],
#     'nutrition': {}},
#    {'item': 'Grilled Swordfish',
#     'price': '$25.00',
#     'ingredients': ['Clams', 'basil', 'seed'],
#     'nutrition': {}},
#    {'item': 'Herb-Crusted Salmon',
#     'price': '$25.00',
#     'ingredients': ['Eggplant',
#      'caponata',
#      'fennel',
#      'roasted',
#      'tomato',
#      'oregano',
#      'broth'],
#     'nutrition': {}},
#    {'item': 'Stuffed Chicken Breast',
#     'price': '$22.00',
#     'ingredients': ['Spinach', 'goat', 'cheese', 'farro', 'risotto'],
#     'nutrition': {}},
#    {'item': 'Bacon-Wrapped Pork Tenderloin',
#     'price': '$22.00',
#     'ingredients': ['ham',
#      'leeks',
#      'sprouts',
#      'whole',
#      'grain',
#      'vinaigrette'],
#     'nutrition': {}},
#    {'item': 'Grilled Angus Rib-Eye Steak',
#     'price': '$34.00',
#     'ingredients': ['Marinated',
#      'roasted',
#      'crimini',
#      'mushrooms',
#      'cipollini',
#      'onions',
#      'butter',
#      'potato',
#      'puree'],
#     'nutrition': {}},
#    {'item': 'Baked Eggplant',
#     'price': '$17.00',
#     'ingredients': ['tomato', 'basil', 'mozzarella', 'nuts'],
#     'nutrition': {}},
#    {'item': 'Lamb Chop',
#     'price': '$36.00',
#     'ingredients': ['cranberry', 'beans', 'eggplant', 'dill', 'puree'],
#     'nutrition': {}},
#    {'item': 'Lamb Burger',
#     'price': '$16.00',
#     'ingredients': ['Pickled',
#      'cucumber',
#      'onion',
#      'feta',
#      'arugula',
#      'olive',
#      'aioli',
#      'fried',
#      'potatoes'],
#     'nutrition': {}},
#    {'item': 'Butternut Tortelloni',
#     'price': '$13.00',
#     'ingredients': ['parmesan'],
#     'nutrition': {}},
#    {'item': 'Chicken Souviaki Kebob',
#     'price': '$12.00',
#     'ingredients': ['tzatziki', 'salad'],
#     'nutrition': {}},
#    {'item': 'Grilled Hanger Steak',
#     'price': '$24.00',
#     'ingredients': ['potatoes', 'roasted', 'arugula', 'chimichurri'],
#     'nutrition': {}},
#    {'item': 'Grouper',
#     'price': '$25.00',
#     'ingredients': ['Shrimp',
#      'mussels',
#      'clams',
#      'bouillabaisse',
#      'broth',
#      'rouille',
#      'garlic',
#      'bread'],
#     'nutrition': {}},
#    {'item': 'Lemon Linguini',
#     'price': '$12.00',
#     'ingredients': ['pesto',
#      'zucchini',
#      'sundried',
#      'tomatoes',
#      'roasted',
#      'peppers',
#      'mushrooms',
#      'feta'],
#     'nutrition': {}},
#    {'item': 'Mushroom Linguini Carbonara',
#     'price': '$14.00',
#     'ingredients': ['bacon', 'parmesan'],
#     'nutrition': {}},
#    {'item': 'Penne Bolognese',
#     'price': '$14.00',
#     'ingredients': ['meat', 'sauce'],
#     'nutrition': {}},
#    {'item': 'Rack of Lamb',
#     'price': '$36.00',
#     'ingredients': ['Tomato',
#      'scallion',
#      'feta',
#      'cheese',
#      'potatoes',
#      'olive'],
#     'nutrition': {}},
#    {'item': 'Ravioli of the Day',
#     'price': '$12.00',
#     'ingredients': ['Ravioli'],
#     'nutrition': {}},
#    {'item': 'Seared Salmon',
#     'price': '$17.00',
#     'ingredients': ['spinach',
#      'quinoa',
#      'citrus',
#      'grain',
#      'mustard',
#      'sauce'],
#     'nutrition': {}},
#    {'item': 'Shrimp & Artichoke Risotto',
#     'price': '$14.00',
#     'ingredients': ['wine', 'butter'],
#     'nutrition': {}},
#    {'item': "Shrimp Giorgio's",
#     'price': '$14.00',
#     'ingredients': ['fresh',
#      'sundried',
#      'tomatoes',
#      'spinach',
#      'feta',
#      'basil',
#      'butter'],
#     'nutrition': {}},
#    {'item': 'Slow Roasted Short Rib',
#     'price': '$24.00',
#     'ingredients': ['Pastrami',
#      'spice',
#      'braised',
#      'local',
#      'greens',
#      'puree'],
#     'nutrition': {}},
#    {'item': 'Grilled Bronzino',
#     'price': '$34.00',
#     'ingredients': ['fennel', 'sofrito', 'olive', 'oil', 'fennel'],
#     'nutrition': {}},
#    {'item': 'Stuffed Chicken Breast',
#     'price': '$25.00',
#     'ingredients': ['spinach', 'goat', 'cheese', 'quinoa', 'pecans', 'yogurt'],
#     'nutrition': {}},
#    {'item': 'Chargrilled Organic Scottish Salmon',
#     'price': '$27.00',
#     'ingredients': ['chickpea', 'tahini', 'puree', 'broccolini'],
#     'nutrition': {}},
#    {'item': 'Australian Lamb Chops',
#     'price': '$36.00',
#     'ingredients': ['pistachio',
#      'oil',
#      'oregano',
#      'roasted',
#      'fingerlings',
#      'tzatziki'],
#     'nutrition': {}},
#    {'item': 'Local Harvest Ribeye',
#     'price': '$35.00',
#     'ingredients': ['roasted', 'crimini', 'mushrooms'],
#     'nutrition': {}},
#    {'item': 'Scallops, Shrimp, Claims',
#     'price': '$30.00',
#     'ingredients': ['fried',
#      'garlic',
#      'chilis',
#      'wine',
#      'sauce',
#      'bread',
#      'crumbs'],
#     'nutrition': {}},
#    {'item': 'Grilled Pork Chop',
#     'price': '$28.00',
#     'ingredients': ['asparagus', 'onion', 'romesco', 'sauce'],
#     'nutrition': {}},
#    {'item': 'Butternut Squash Puree',
#     'price': '$6.00',
#     'ingredients': ['Pumpkin', 'seeds', 'raisins'],
#     'nutrition': {}},
#    {'item': 'Potato Puree',
#     'price': '$6.00',
#     'ingredients': ['butter'],
#     'nutrition': {}},
#    {'item': 'Spinach and Goat Cheese Gratin',
#     'price': '$6.00',
#     'ingredients': ['Spinach', 'Goat', 'Cheese', 'Gratin'],
#     'nutrition': {}},
#    {'item': 'Couscous and Mushroom Pilaf',
#     'price': '$6.00',
#     'ingredients': ['almonds'],
#     'nutrition': {}},
#    {'item': 'Cranberry Bean Stew',
#     'price': '$6.00',
#     'ingredients': [],
#     'nutrition': {}},
#    {'item': 'Braised Local Greens',
#     'price': '$6.00',
#     'ingredients': ['Olive', 'oil', 'garlic'],
#     'nutrition': {}},
#    {'item': 'Roasted Fingerling Potatoes',
#     'price': '$6.00',
#     'ingredients': ['chimichurri'],
#     'nutrition': {}},
#    {'item': 'Sauteed Squash',
#     'price': '$6.00',
#     'ingredients': ['olives', 'basil', 'yogurt'],
#     'nutrition': {}},
#    {'item': 'Charred Broccolini, Anchovy, Pecorino',
#     'price': '$9.00',
#     'ingredients': ['Broccolini', 'Anchovy', 'Pecorino'],
#     'nutrition': {}},
#    {'item': 'Sauteed Mushrooms, Garlic Confit',
#     'price': '$9.00',
#     'ingredients': ['Sauteed', 'Mushrooms', 'Garlic', 'Confit'],
#     'nutrition': {}},
#    {'item': 'Roasted Fingerling Potatoes',
#     'price': '$9.00',
#     'ingredients': ['Potatoes'],
#     'nutrition': {}},
#    {'item': 'Charred Asapagus, Black Olive, Tzatziki, Grated Parmesan',
#     'price': '$9.00',
#     'ingredients': ['Olive', 'Tzatziki', 'Grated', 'Parmesan'],
#     'nutrition': {}},
#    {'item': 'Avgolemono',
#     'price': '$6.00',
#     'ingredients': ['Greek', 'chicken', 'vegetable', 'soup'],
#     'nutrition': {}},
#    {'item': 'Bruschetta',
#     'price': '$5.00',
#     'ingredients': ['tapenade', 'marinated', 'tomato', 'feta', 'cheese'],
#     'nutrition': {}},
#    {'item': 'Crispy Calamari',
#     'price': '$7.00',
#     'ingredients': ['fried', 'tomato', 'pepperoncini', 'aioli'],
#     'nutrition': {}},
#    {'item': 'Spiced Pita and Spreads',
#     'price': '$6.00',
#     'ingredients': ['chickpea', 'hummus', 'tzatziki'],
#     'nutrition': {}},
#    {'item': 'Baked Haloumi',
#     'price': '$9.00',
#     'ingredients': ['tomatoes', 'olives', 'baguette'],
#     'nutrition': {}},
#    {'item': 'Bacalao Fritters',
#     'price': '$7.00',
#     'ingredients': ['Fritters'],
#     'nutrition': {}},
#    {'item': 'Seasonal Farm Salad',
#     'price': '$11.00',
#     'ingredients': [],
#     'nutrition': {}},
#    {'item': 'Parizade Salad',
#     'price': '$11.00',
#     'ingredients': ['Strawberries', 'almonds', 'cheese', 'vinaigrette'],
#     'nutrition': {}},
#    {'item': 'Greek Horiatiki Salad',
#     'price': '$12.00',
#     'ingredients': ['organic',
#      'tomatoes',
#      'cucumber',
#      'feta',
#      'peppers',
#      'oregano',
#      'wine',
#      'vinaigrette'],
#     'nutrition': {}},
#    {'item': 'Caesar Salad',
#     'price': '$10.00',
#     'ingredients': ['reggiano', 'parmesan'],
#     'nutrition': {}},
#    {'item': 'Caprese Salad Lunch',
#     'price': '$12.00',
#     'ingredients': ['Tomato',
#      'basil',
#      'fresh',
#      'mozzarella',
#      'arugula',
#      'fruity',
#      'olive',
#      'oil',
#      'vinegar'],
#     'nutrition': {}},
#    {'item': 'Chopped Salad Lunch',
#     'price': '$7.00',
#     'ingredients': ['arugula', 'cucumbers', 'dill', 'yogurt', 'dressing'],
#     'nutrition': {}},
#    {'item': 'Greek Salad Lunch',
#     'price': '$10.00',
#     'ingredients': ['Tomatoes',
#      'cucumbers',
#      'peppers',
#      'olives',
#      'feta',
#      'greens',
#      'Gluten'],
#     'nutrition': {}},
#    {'item': 'Roasted Beet Salad Lunch',
#     'price': '$10.00',
#     'ingredients': ['Goat',
#      'cheese',
#      'arugula',
#      'walnuts',
#      'cider',
#      'vinaigrette'],
#     'nutrition': {}},
#    {'item': 'Spicy Greens Lunch',
#     'price': '$10.00',
#     'ingredients': ['Goat', 'cheese', 'prosciutto', 'grapes', 'Gluten'],
#     'nutrition': {}},
#    {'item': 'Tuscan Kale Salad Lunch',
#     'price': '$9.00',
#     'ingredients': ['beets', 'nuts', 'chili', 'feta', 'vinaigrette', 'Gluten'],
#     'nutrition': {}},
#    {'item': 'Spiced Pita Lunch',
#     'price': '$6.00',
#     'ingredients': ['Chopped', 'salad', 'hummus'],
#     'nutrition': {}},
#    {'item': 'Tomato Bruschetta Lunch',
#     'price': '$5.00',
#     'ingredients': ['tapenade'],
#     'nutrition': {}},
#    {'item': 'Crispy Calamari Lunch',
#     'price': '$7.00',
#     'ingredients': ['aioli'],
#     'nutrition': {}},
#    {'item': 'Soup of the Day Lunch',
#     'price': '$6.00',
#     'ingredients': ['restaurant'],
#     'nutrition': {}},
#    {'item': 'Grilled Shrimp Saganaki Lunch',
#     'price': '$8.00',
#     'ingredients': ['tomato', 'feta', 'dill', 'Gluten'],
#     'nutrition': {}},
#    {'item': 'Tomato Crostini Lunch',
#     'price': '$12.00',
#     'ingredients': ['Tapenade', 'feta', 'basil'],
#     'nutrition': {}},
#    {'item': 'Goat Cheese Herb Toast Lunch',
#     'price': '$6.00',
#     'ingredients': ['grilled', 'vegetables'],
#     'nutrition': {}},
#    {'item': 'Roast Turkey Club Lunch',
#     'price': '$9.00',
#     'ingredients': ['Whole', 'wheat', 'bacon', 'lettuce', 'tomato', 'aioli'],
#     'nutrition': {}},
#    {'item': 'Parizade Burger',
#     'price': '$12.00',
#     'ingredients': ['gruyere', 'grilled', 'onions', 'mustard', 'aioli'],
#     'nutrition': {}},
#    {'item': 'BLT Flatbread',
#     'price': '$12.00',
#     'ingredients': ['caesar', 'salad'],
#     'nutrition': {}},
#    {'item': 'Proscuitto Panini',
#     'price': '$11.00',
#     'ingredients': ['Prosciutto', 'mozzarella', 'romesco', 'aioli'],
#     'nutrition': {}},
#    {'item': 'Grilled Eggplant Caprese Panini',
#     'price': '$10.00',
#     'ingredients': ['fresh', 'mozzarella', 'tomato', 'basil'],
#     'nutrition': {}},
#    {'item': 'Italian Cheese Panini',
#     'price': '$9.00',
#     'ingredients': ['mozzarella', 'sundried', 'tomato', 'tapenade'],
#     'nutrition': {}},
#    {'item': 'Ravioli of the Day Lunch',
#     'price': '$12.00',
#     'ingredients': ['restaurant'],
#     'nutrition': {}},
#    {'item': 'Lemon Linguini',
#     'price': '$14.00',
#     'ingredients': ['vegetables',
#      'spinach',
#      'sundried',
#      'tomato',
#      'feta',
#      'pesto'],
#     'nutrition': {}},
#    {'item': "Shrimp Giorgio's",
#     'price': '$16.00',
#     'ingredients': ['spinach', 'sundried', 'tomato', 'feta', 'basil'],
#     'nutrition': {}},
#    {'item': 'Tagliatelle',
#     'price': '$13.00',
#     'ingredients': ['clam', 'sauce', 'salami', 'garlic', 'oregano', 'chilis'],
#     'nutrition': {}},
#    {'item': 'Greek Lamb Pastitsio',
#     'price': '$14.00',
#     'ingredients': ['goat', 'cheese'],
#     'nutrition': {}},
#    {'item': 'Chicken Souvlaki Kebob',
#     'price': '$15.00',
#     'ingredients': ['tzatziki', 'arugula', 'Greek', 'salad', 'pita'],
#     'nutrition': {}},
#    {'item': 'Shrimp and Artichoke Risotto',
#     'price': '$15.00',
#     'ingredients': ['dill', 'citrus', 'butter', 'parmesan'],
#     'nutrition': {}},
#    {'item': 'Seared Salmon',
#     'price': '$17.00',
#     'ingredients': ['spinach', 'quinoa', 'citrus', 'mustard', 'sauce'],
#     'nutrition': {}},
#    {'item': 'Baked Eggplant Lunch',
#     'price': '$13.00',
#     'ingredients': ['Fresh',
#      'mozzarella',
#      'Parmesan',
#      'tomato',
#      'basil',
#      'sauce'],
#     'nutrition': {}},
#    {'item': 'Butternut Tortellini Lunch',
#     'price': '$13.00',
#     'ingredients': ['Parmesan'],
#     'nutrition': {}},
#    {'item': 'Chilled Shrimp Orzo Lunch',
#     'price': '$14.00',
#     'ingredients': ['Arugula', 'feta', 'grape', 'tomatoes', 'dill', 'pesto'],
#     'nutrition': {}},
#    {'item': 'Lamb Orzo Lunch',
#     'price': '$14.00',
#     'ingredients': ['lamb', 'meatballs', 'tomato', 'olives', 'eggplant'],
#     'nutrition': {}},
#    {'item': 'Mushroom Linguini Carbonara Lunch',
#     'price': '$14.00',
#     'ingredients': ['bacon', 'Parmesan'],
#     'nutrition': {}},
#    {'item': 'Penne Bolognese Lunch',
#     'price': '$14.00',
#     'ingredients': ['meat', 'sauce'],
#     'nutrition': {}},
#    {'item': 'Crispy Eggplant Parmesan',
#     'price': '$14.00',
#     'ingredients': ['fresh', 'mozzarella', 'tomato', 'basil', 'sauce'],
#     'nutrition': {}},
#    {'item': 'Organic Farro',
#     'price': '$14.00',
#     'ingredients': ['mushrooms', 'greens', 'roasted', 'garlic'],
#     'nutrition': {}},
#    {'item': 'Prix Fixe Lunch',
#     'price': '$17.00',
#     'ingredients': ['Lunch'],
#     'nutrition': {}},
#    {'item': 'Tunisian Orange Cake',
#     'price': '$9.00',
#     'ingredients': ['Cake'],
#     'nutrition': {}},
#    {'item': 'Local Chocolates',
#     'price': '$8.00',
#     'ingredients': ['Chocolates'],
#     'nutrition': {}},
#    {'item': 'Franciscan Monk Cake',
#     'price': '$9.00',
#     'ingredients': ['Cake'],
#     'nutrition': {}},
#    {'item': 'Vanilla Bean Creme Brulee',
#     'price': '$7.00',
#     'ingredients': [],
#     'nutrition': {}},
#    {'item': 'Banana Rum Napoleon',
#     'price': '$7.00+',
#     'ingredients': ['Banana'],
#     'nutrition': {}},
#    {'item': 'Black Velvet Praline Torte',
#     'price': '$7.00+',
#     'ingredients': ['Praline', 'Torte'],
#     'nutrition': {}}]},
#  {'Name': "McDonald's",
#   'Location': (36.0012233, -78.9414137),
#   'Menu': [{'item': 'World Famous Fries',
#     'price': '',
#     'ingredients': ['quality',
#      'potatoes',
#      'cooked',
#      'canola',
#      'oil',
#      'fat',
#      'serving']},
#    {'item': 'Apple Slices', 'price': '', 'ingredients': []},
#    {'item': 'Side Salad',
#     'price': '',
#     'ingredients': ['greens', 'succulent', 'grape', 'tomatoes', 'carrots']},
#    {'item': "Fruit 'N Yogurt Parfait",
#     'price': '',
#     'ingredients': ['wholesome',
#      'yogurt',
#      'blueberries',
#      'strawberries',
#      'all',
#      'crunchy',
#      'granola']},
#    {'item': 'Fruit & Walnuts',
#     'price': '',
#     'ingredients': ['apples', 'grapes', 'walnuts', 'yogurt']},
#    {'item': 'Angus Chipotle BBQ Bacon Snack Wrap',
#     'price': '',
#     'ingredients': ['beef',
#      'smoky',
#      'BBQ',
#      'sauce',
#      'onions',
#      'pickles',
#      'cheese',
#      'flour',
#      'tortilla']},
#    {'item': 'Angus Bacon & Cheese Snack Wrap',
#     'price': '',
#     'ingredients': ['savory',
#      'beef',
#      'bacon',
#      'melty',
#      'cheese',
#      'tangy',
#      'pickles',
#      'onions',
#      'flour',
#      'tortilla']},
#    {'item': 'Angus Deluxe Snack Wrap',
#     'price': '',
#     'ingredients': ['savory',
#      'beef',
#      'fresh',
#      'tomato',
#      'melty',
#      'cheese',
#      'pickles',
#      'lettuce',
#      'onions',
#      'flour',
#      'tortilla']},
#    {'item': 'Angus Mushroom & Swiss Snack Wrap',
#     'price': '',
#     'ingredients': ['savory',
#      'beef',
#      'tasty',
#      'mushrooms',
#      'melty',
#      'cheese',
#      'flour',
#      'tortilla']},
#    {'item': 'Chipotle BBQ Snack Wrap (Crispy)',
#     'price': '',
#     'ingredients': ['crispy', 'chicken', 'BBQ', 'sauce', 'flour', 'tortilla']},
#    {'item': 'Chipotle BBQ Snack Wrap (Grilled)',
#     'price': '',
#     'ingredients': ['Plump',
#      'grilled',
#      'chicken',
#      'BBQ',
#      'sauce',
#      'flour',
#      'tortilla']},
#    {'item': 'Honey Mustard Snack Wrap (Crispy)',
#     'price': '',
#     'ingredients': ['crispy', 'chicken', 'honey', 'mustard']},
#    {'item': 'Honey Mustard Snack Wrap (Grilled)',
#     'price': '',
#     'ingredients': ['grilled',
#      'chicken',
#      'cheddar',
#      'cheeses',
#      'tangy',
#      'honey',
#      'mustard',
#      'sauce']},
#    {'item': 'Ranch Snack Wrap (Crispy)',
#     'price': '',
#     'ingredients': ['crispy', 'chicken', 'tangy', 'sauce']},
#    {'item': 'Ranch Snack Wrap (Grilled)',
#     'price': '',
#     'ingredients': ['Feast',
#      'grilled',
#      'chicken',
#      'tangy',
#      'sauce',
#      'tortilla']},
#    {'item': 'Mac Snack Wrap',
#     'price': '',
#     'ingredients': ['sandwich', 'snacking']},
#    {'item': 'Chicken McBites',
#     'price': '',
#     'ingredients': ['bites', 'chicken', 'meat', 'deliciously']},
#    {'item': 'Premium Bacon Ranch Salad',
#     'price': '',
#     'ingredients': ['Fresh',
#      'greens',
#      'sumptuous',
#      'grape',
#      'tomatoes',
#      'bacon']},
#    {'item': 'Premium Bacon Ranch Salad with Crispy Chicken',
#     'price': '',
#     'ingredients': ['Fresh',
#      'greens',
#      'sumptuous',
#      'grape',
#      'tomatoes',
#      'carrots',
#      'cheddar',
#      'cheeses',
#      'bacon',
#      'meat',
#      'chicken']},
#    {'item': 'Premium Bacon Ranch Salad with Grilled Chicken',
#     'price': '',
#     'ingredients': ['Fresh', 'greens', 'grilled', 'chicken', 'dressing']},
#    {'item': 'Premium Caesar Salad',
#     'price': '',
#     'ingredients': ['kinds',
#      'fresh',
#      'greens',
#      'sumptuous',
#      'grape',
#      'tomatoes',
#      'carrots',
#      'parmesan',
#      'cheese']},
#    {'item': 'Premium Caesar Salad with Crispy Chicken',
#     'price': '',
#     'ingredients': ['Crispy',
#      'meat',
#      'chicken',
#      'deliciously',
#      'fresh',
#      'greens',
#      'parmesan',
#      'cheese',
#      'dressing']},
#    {'item': 'Premium Caesar Salad with Grilled Chicken',
#     'price': '',
#     'ingredients': ['Salad', 'Grilled', 'Chicken']},
#    {'item': 'Premium Southwest Salad',
#     'price': '',
#     'ingredients': ['greens',
#      'corn',
#      'savory',
#      'beans',
#      'poblano',
#      'peppers',
#      'chili',
#      'tortilla']},
#    {'item': 'Premium Southwest Salad with Crispy Chicken',
#     'price': '',
#     'ingredients': ['Crispy',
#      'chicken',
#      'fresh',
#      'greens',
#      'tomatoes',
#      'corn',
#      'savory',
#      'beans',
#      'poblano',
#      'peppers',
#      'cheddar',
#      'cheeses',
#      'chili',
#      'tortilla']},
#    {'item': 'Premium Southwest Salad with Grilled Chicken',
#     'price': '',
#     'ingredients': ['chicken',
#      'fresh',
#      'greens',
#      'tomatoes',
#      'corn',
#      'savory',
#      'beans',
#      'poblano',
#      'peppers',
#      'cheddar',
#      'cheeses',
#      'chili',
#      'tortilla']},
#    {'item': 'Side Salad',
#     'price': '',
#     'ingredients': ['greens', 'succulent', 'grape', 'tomatoes', 'carrots']},
#    {'item': 'Fruit & Walnuts',
#     'price': '',
#     'ingredients': ['apples', 'grapes', 'walnuts', 'yogurt']},
#    {'item': 'Angus Chipotle BBQ Bacon',
#     'price': '',
#     'ingredients': ['beef',
#      'smoky',
#      'BBQ',
#      'sauce',
#      'onions',
#      'pickles',
#      'cheese',
#      'all',
#      'sesame',
#      'seed',
#      'bun']},
#    {'item': 'Angus Bacon & Cheese',
#     'price': '',
#     'ingredients': ['beef',
#      'patty',
#      'bakery',
#      'bun',
#      'savory',
#      'bacon',
#      'cheese',
#      'onion',
#      'pickles']},
#    {'item': 'Angus Deluxe',
#     'price': '',
#     'ingredients': ['beef',
#      'patty',
#      'bakery',
#      'bun',
#      'cheese',
#      'farm',
#      'fresh',
#      'tomato',
#      'lettuce',
#      'onion',
#      'pickles']},
#    {'item': 'Angus Mushroom & Swiss',
#     'price': '',
#     'ingredients': ['beef', 'patty', 'cheese', 'savory', 'mushrooms']},
#    {'item': 'Big Mac',
#     'price': '',
#     'ingredients': ['beef', 'sauce', 'melty', 'cheese', 'onion', 'pickle']},
#    {'item': 'Quarter Pounder with Cheese',
#     'price': '',
#     'ingredients': ['cheese', 'beef', 'sesame', 'seed', 'bun']},
#    {'item': 'Double Quarter Pounder with Cheese',
#     'price': '',
#     'ingredients': ['beef', 'patties', 'cheese']},
#    {'item': 'Hamburger',
#     'price': '',
#     'ingredients': ['beef',
#      'patty',
#      'tangy',
#      'pickles',
#      'onions',
#      'ketchup',
#      'mustard',
#      'all',
#      'bun']},
#    {'item': 'Cheeseburger',
#     'price': '',
#     'ingredients': ['melty',
#      'cheese',
#      'beef',
#      'patty',
#      'pickles',
#      'onions',
#      'ketchup',
#      'mustard',
#      'bun']},
#    {'item': 'Double Cheeseburger',
#     'price': '',
#     'ingredients': ['cheese',
#      'patties',
#      'pickles',
#      'onions',
#      'ketchup',
#      'mustard',
#      'bun']},
#    {'item': 'McDouble',
#     'price': '',
#     'ingredients': ['melty',
#      'cheese',
#      'beef',
#      'patties',
#      'pickles',
#      'onions',
#      'ketchup',
#      'mustard',
#      'bun']},
#    {'item': 'Filet-O-Fish',
#     'price': '',
#     'ingredients': ['filet',
#      'fish',
#      'ocean',
#      'tangy',
#      'sauce',
#      'steamed',
#      'bun']},
#    {'item': 'Southern Style Crispy Chicken Sandwich',
#     'price': '',
#     'ingredients': ['meat', 'crispy', 'chicken', 'pickles', 'steamed', 'bun']},
#    {'item': "Big N' Tasty",
#     'price': '',
#     'ingredients': ['beef',
#      'patty',
#      'tomato',
#      'lettuce',
#      'pickles',
#      'onions',
#      'ketchup',
#      'mayonnaise',
#      'dressing',
#      'sesame',
#      'seed',
#      'bun']},
#    {'item': "Big N' Tasty with Cheese",
#     'price': '',
#     'ingredients': ['beef',
#      'patty',
#      'cheese',
#      'tomato',
#      'lettuce',
#      'pickles',
#      'onions',
#      'ketchup',
#      'mayonnaise',
#      'dressing',
#      'sesame',
#      'seed',
#      'bun']},
#    {'item': 'Premium Crispy Chicken Classic Sandwich',
#     'price': '',
#     'ingredients': ['meat',
#      'crispy',
#      'chicken',
#      'filet',
#      'so',
#      'bun',
#      'lettuce',
#      'tomato',
#      'mayonnaise',
#      'dressing']},
#    {'item': 'Premium Grilled Chicken Classic Sandwich',
#     'price': '',
#     'ingredients': ['meat',
#      'grilled',
#      'chicken',
#      'filet',
#      'so',
#      'bun',
#      'lettuce',
#      'tomato',
#      'mayonnaise',
#      'dressing']},
#    {'item': 'Premium Crispy Chicken Club Sandwich',
#     'price': '',
#     'ingredients': ['meat',
#      'crispy',
#      'chicken',
#      'filet',
#      'bacon',
#      'delicious',
#      'bun',
#      'cheese']},
#    {'item': 'Premium Grilled Chicken Club Sandwich',
#     'price': '',
#     'ingredients': ['meat',
#      'grilled',
#      'chicken',
#      'filet',
#      'bacon',
#      'delicious',
#      'bun',
#      'cheese']},
#    {'item': 'Premium Crispy Chicken Ranch BLT Sandwich',
#     'price': '',
#     'ingredients': ['meat',
#      'crispy',
#      'chicken',
#      'filet',
#      'bacon',
#      'sauce',
#      'bun']},
#    {'item': 'Premium Grilled Chicken Ranch BLT Sandwich',
#     'price': '',
#     'ingredients': ['meat',
#      'grilled',
#      'chicken',
#      'filet',
#      'bacon',
#      'sauce',
#      'bun']},
#    {'item': 'McChicken',
#     'price': '',
#     'ingredients': ['crispy', 'chicken', 'bun']},
#    {'item': 'Angus Chipotle BBQ Bacon Snack Wrap',
#     'price': '',
#     'ingredients': ['beef',
#      'smoky',
#      'BBQ',
#      'sauce',
#      'onions',
#      'pickles',
#      'cheese',
#      'flour',
#      'tortilla']},
#    {'item': 'Angus Bacon & Cheese Snack Wrap',
#     'price': '',
#     'ingredients': ['savory',
#      'beef',
#      'bacon',
#      'melty',
#      'cheese',
#      'tangy',
#      'pickles',
#      'onions',
#      'flour',
#      'tortilla']},
#    {'item': 'Angus Deluxe Snack Wrap',
#     'price': '',
#     'ingredients': ['savory',
#      'beef',
#      'fresh',
#      'tomato',
#      'melty',
#      'cheese',
#      'pickles',
#      'lettuce',
#      'onions',
#      'flour',
#      'tortilla']},
#    {'item': 'Angus Mushroom & Swiss Snack Wrap',
#     'price': '',
#     'ingredients': ['savory',
#      'beef',
#      'tasty',
#      'mushrooms',
#      'melty',
#      'cheese',
#      'flour',
#      'tortilla']},
#    {'item': 'Chipotle BBQ Snack Wrap (Crispy)',
#     'price': '',
#     'ingredients': ['crispy', 'chicken', 'BBQ', 'sauce', 'flour', 'tortilla']},
#    {'item': 'Chipotle BBQ Snack Wrap (Grilled)',
#     'price': '',
#     'ingredients': ['Plump',
#      'grilled',
#      'chicken',
#      'BBQ',
#      'sauce',
#      'flour',
#      'tortilla']},
#    {'item': 'Honey Mustard Snack Wrap (Crispy)',
#     'price': '',
#     'ingredients': ['crispy', 'chicken', 'honey', 'mustard']},
#    {'item': 'Honey Mustard Snack Wrap (Grilled)',
#     'price': '',
#     'ingredients': ['grilled',
#      'chicken',
#      'cheddar',
#      'cheeses',
#      'tangy',
#      'honey',
#      'mustard',
#      'sauce']},
#    {'item': 'Ranch Snack Wrap (Crispy)',
#     'price': '',
#     'ingredients': ['crispy', 'chicken', 'tangy', 'sauce']},
#    {'item': 'Ranch Snack Wrap (Grilled)',
#     'price': '',
#     'ingredients': ['grilled', 'chicken', 'tangy', 'sauce', 'tortilla']},
#    {'item': 'Mac Snack Wrap',
#     'price': '',
#     'ingredients': ['sandwich', 'snacking']},
#    {'item': 'McRib',
#     'price': '',
#     'ingredients': ['Flavorful',
#      'pork',
#      'tangy',
#      'barbeque',
#      'sauce',
#      'sandwich']},
#    {'item': 'Chicken McNuggets',
#     'price': '',
#     'ingredients': ['chicken', 'meat', 'tempura', 'batter']},
#    {'item': 'Chicken McBites',
#     'price': '',
#     'ingredients': ['bites', 'chicken', 'meat', 'deliciously']},
#    {'item': 'Chicken Selects Premium Breast Strips',
#     'price': '',
#     'ingredients': ['Crispy', 'all', 'chicken', 'sauces']},
#    {'item': 'Caramel Apple Parfait',
#     'price': '',
#     'ingredients': ['yogurt', 'apples']},
#    {'item': 'Vanilla Reduced Fat Ice Cream Cone',
#     'price': '',
#     'ingredients': ['crispy']},
#    {'item': 'Kiddie Cone',
#     'price': '',
#     'ingredients': ['fat', 'ice', 'crispy']},
#    {'item': 'Caramel Apple Sundae',
#     'price': '',
#     'ingredients': ['Delicious', 'fat', 'ice', 'apples', 'warm', 'peanuts']},
#    {'item': 'Strawberry Sundae',
#     'price': '',
#     'ingredients': ['fat', 'ice', 'strawberries', 'strawberry', 'sauce']},
#    {'item': 'Hot Caramel Sundae',
#     'price': '',
#     'ingredients': ['fat', 'ice', 'warm']},
#    {'item': 'Hot Fudge Sundae',
#     'price': '',
#     'ingredients': ['fat', 'ice', 'chocolatey', 'fudge', 'sauce']},
#    {'item': "McFlurry with M&M's",
#     'price': '',
#     'ingredients': ['fat', 'ice', 'candies']},
#    {'item': 'McFlurry with Oreo Cookies',
#     'price': '',
#     'ingredients': ['oreo', 'cookies']},
#    {'item': "McFlurry with Reese's",
#     'price': '',
#     'ingredients': ['fat', 'ice', 'peanut', 'butter', 'cups']},
#    {'item': 'McCafe Chocolate Shake',
#     'price': '',
#     'ingredients': ['deliciously', 'fat', 'ice', 'chocolate', 'syrup']},
#    {'item': 'McCafe Strawberry Shake',
#     'price': '',
#     'ingredients': ['fat', 'ice', 'strawberry', 'deliciousness']},
#    {'item': 'McCafe Vanilla Shake',
#     'price': '',
#     'ingredients': ['fat', 'ice']},
#    {'item': 'McCafe Shamrock Shake', 'price': '', 'ingredients': []},
#    {'item': 'Baked Apple  Pie',
#     'price': '',
#     'ingredients': ['delicious', 'apples', 'baked', 'pastry']},
#    {'item': 'Cinnamon Melts', 'price': '', 'ingredients': ['warm']},
#    {'item': 'Soft Baked Chocolate Chip Cookie',
#     'price': '',
#     'ingredients': ['taste', 'cookie', 'chocolate', 'chips']},
#    {'item': 'Soft Baked Oatmeal Raisin Cookie',
#     'price': '',
#     'ingredients': ['Cookie', 'raisins']},
#    {'item': 'Soft Baked Sugar Cookie', 'price': '', 'ingredients': ['cookie']},
#    {'item': 'McDonaldland Cookies',
#     'price': '',
#     'ingredients': ['McDonaldland', 'Cookies']},
#    {'item': 'Premium Roast Coffee',
#     'price': '',
#     'ingredients': ['arabica', 'beans', 'freshly', 'brewed']},
#    {'item': 'Premium Roast Iced Coffee',
#     'price': '',
#     'ingredients': ['arabica', 'beans', 'syrups']},
#    {'item': 'McCafe Mocha',
#     'price': '',
#     'ingredients': ['arabica',
#      'beans',
#      'steamed',
#      'whole',
#      'nonfat',
#      'milk',
#      'chocolate',
#      'syrup',
#      'chocolate']},
#    {'item': 'McCafe Peppermint Mocha',
#     'price': '',
#     'ingredients': ['arabica',
#      'beans',
#      'steamed',
#      'whole',
#      'nonfat',
#      'milk',
#      'chocolate',
#      'syrup',
#      'peppermint',
#      'flavor',
#      'all',
#      'chocolate']},
#    {'item': 'McCafe Caramel Mocha',
#     'price': '',
#     'ingredients': ['arabica',
#      'beans',
#      'steamed',
#      'whole',
#      'nonfat',
#      'milk',
#      'chocolate',
#      'syrup']},
#    {'item': 'McCafe Latte',
#     'price': '',
#     'ingredients': ['arabica',
#      'beans',
#      'steamed',
#      'whole',
#      'nonfat',
#      'milk',
#      'syrups']},
#    {'item': 'McCafe Cappuccino',
#     'price': '',
#     'ingredients': ['arabica',
#      'beans',
#      'steamed',
#      'whole',
#      'nonfat',
#      'milk',
#      'syrups',
#      'milk']},
#    {'item': 'McCafe Hot Chocolate',
#     'price': '',
#     'ingredients': ['steamed',
#      'whole',
#      'nonfat',
#      'milk',
#      'chocolate',
#      'syrup',
#      'chocolate']},
#    {'item': 'McCafe Peppermint Hot Chocolate',
#     'price': '',
#     'ingredients': ['chocolate',
#      'syrup',
#      'peppermint',
#      'flavor',
#      'steamed',
#      'whole',
#      'nonfat',
#      'milk',
#      'all',
#      'chocolate']},
#    {'item': 'McCafe Caramel Hot Chocolate',
#     'price': '',
#     'ingredients': ['chocolate',
#      'steamed',
#      'whole',
#      'nonfat',
#      'milk',
#      'chocolate',
#      'syrup']},
#    {'item': 'McCafe Iced Mocha',
#     'price': '',
#     'ingredients': ['espresso',
#      'arabica',
#      'beans',
#      'whole',
#      'nonfat',
#      'milk',
#      'chocolate',
#      'syrup',
#      'chocolate']},
#    {'item': 'McCafe Iced Caramel Mocha',
#     'price': '',
#     'ingredients': ['espresso',
#      'arabica',
#      'beans',
#      'whole',
#      'nonfat',
#      'milk',
#      'chocolate',
#      'syrup']},
#    {'item': 'McCafe Iced Latte',
#     'price': '',
#     'ingredients': ['espresso',
#      'arabica',
#      'beans',
#      'whole',
#      'nonfat',
#      'milk',
#      'syrup']},
#    {'item': 'McCafe Frappe Mocha',
#     'price': '',
#     'ingredients': ['chocolate', 'flavor', 'coffee', 'ice', 'chocolate']},
#    {'item': 'McCafe Frappe Caramel',
#     'price': '',
#     'ingredients': ['coffee', 'ice']},
#    {'item': 'McCafe Strawberry Banana Real Fruit Smoothie',
#     'price': '',
#     'ingredients': ['strawberry', 'banana', 'ice', 'fat', 'yogurt']},
#    {'item': 'McCafe Wild Berry Real Fruit Smoothie',
#     'price': '',
#     'ingredients': ['strawberry', 'blueberry', 'ice', 'fat', 'yogurt']},
#    {'item': 'McCafe Mango Pineapple Real Fruit Smoothie',
#     'price': '',
#     'ingredients': ['mango', 'pineapple', 'fat', 'yogurt', 'ice']},
#    {'item': 'McCafe Frozen Strawberry Lemonade',
#     'price': '',
#     'ingredients': ['Tangy', 'refreshment']},
#    {'item': 'McCafe Chocolate Shake',
#     'price': '',
#     'ingredients': ['deliciously', 'fat', 'ice', 'chocolate', 'syrup']},
#    {'item': 'McCafe Strawberry Shake',
#     'price': '',
#     'ingredients': ['fat', 'ice', 'strawberry', 'deliciousness']},
#    {'item': 'McCafe Vanilla Shake',
#     'price': '',
#     'ingredients': ['fat', 'ice']},
#    {'item': 'McCafe Shamrock Shake', 'price': '', 'ingredients': []},
#    {'item': '1% Low Fat Milk Jug',
#     'price': '',
#     'ingredients': ['Wholesome', 'fat', 'milk']},
#    {'item': 'Fat Free Chocolate Milk Jug',
#     'price': '',
#     'ingredients': ['Chocolate', 'fat', 'milk']},
#    {'item': 'Minute Maid Apple Juice Box',
#     'price': '',
#     'ingredients': ['apple', 'juice', 'vitamin']},
#    {'item': 'Dasani Water',
#     'price': '',
#     'ingredients': ['minerals', 'refreshment']},
#    {'item': 'Coca-Cola', 'price': '', 'ingredients': []},
#    {'item': 'Diet Coke', 'price': '', 'ingredients': ['cola', 'calories']},
#    {'item': 'Dr Pepper', 'price': '', 'ingredients': ['Taste', 'flavors']},
#    {'item': 'Diet Dr Pepper',
#     'price': '',
#     'ingredients': ['flavors', 'calories']},
#    {'item': 'Sprite',
#     'price': '',
#     'ingredients': ['Delicious', 'taste', 'caffeine']},
#    {'item': 'Hi-C Orange Lavaburst',
#     'price': '',
#     'ingredients': ['Delicious', 'taste']},
#    {'item': 'Powerade Mountain Berry Blast', 'price': '', 'ingredients': []},
#    {'item': 'Iced Tea', 'price': '', 'ingredients': ['tea', 'ice']},
#    {'item': 'Premium Roast Coffee',
#     'price': '',
#     'ingredients': ['arabica', 'beans', 'freshly', 'brewed']},
#    {'item': 'Premium Roast Iced Coffee',
#     'price': '',
#     'ingredients': ['arabica', 'beans', 'syrups']},
#    {'item': 'Minute Maid Premium Orange Juice',
#     'price': '',
#     'ingredients': ['juice', 'vitamin']},
#    {'item': 'Sweet Tea', 'price': '', 'ingredients': ['tea']},
#    {'item': 'Fruit & Maple Oatmeal',
#     'price': '',
#     'ingredients': ['servings',
#      'natural',
#      'oats',
#      'apples',
#      'cranberries',
#      'varieties',
#      'raisins',
#      'sugar']},
#    {'item': "Fruit 'N Yogurt Parfait",
#     'price': '',
#     'ingredients': ['wholesome',
#      'yogurt',
#      'blueberries',
#      'strawberries',
#      'all',
#      'crunchy',
#      'granola']},
#    {'item': 'Fruit & Walnuts',
#     'price': '',
#     'ingredients': ['apples', 'grapes', 'walnuts', 'yogurt']},
#    {'item': 'Egg McMuffin',
#     'price': '',
#     'ingredients': ['sandwich',
#      'freshly',
#      'egg',
#      'bacon',
#      'melty',
#      'cheese',
#      'freshly',
#      'muffin']},
#    {'item': 'Sausage McMuffin',
#     'price': '',
#     'ingredients': ['muffin',
#      'savory',
#      'sausage',
#      'hot',
#      'griddle',
#      'melty',
#      'cheese']},
#    {'item': 'Sausage McMuffin with Egg',
#     'price': '',
#     'ingredients': ['muffin',
#      'savory',
#      'sausage',
#      'hot',
#      'griddle',
#      'melty',
#      'cheese',
#      'freshly',
#      'egg']},
#    {'item': 'Bacon&comma Egg & Cheese Biscuit',
#     'price': '',
#     'ingredients': ['buttermilk',
#      'biscuit',
#      'bacon',
#      'egg',
#      'melty',
#      'cheese']},
#    {'item': 'Sausage Biscuit',
#     'price': '',
#     'ingredients': ['biscuit', 'sausage', 'hot', 'griddle']},
#    {'item': 'Sausage Biscuit with Egg',
#     'price': '',
#     'ingredients': ['buttermilk',
#      'biscuit',
#      'savory',
#      'sausage',
#      'hot',
#      'griddle',
#      'egg']},
#    {'item': 'Bacon&comma Egg & Cheese McGriddles',
#     'price': '',
#     'ingredients': ['warm',
#      'griddle',
#      'cakes',
#      'taste',
#      'baked',
#      'bacon',
#      'egg',
#      'melty',
#      'cheese']},
#    {'item': 'Sausage McGriddles',
#     'price': '',
#     'ingredients': ['warm',
#      'griddle',
#      'cakes',
#      'taste',
#      'baked',
#      'savory',
#      'sausage']},
#    {'item': 'Sausage&comma Egg & Cheese McGriddles',
#     'price': '',
#     'ingredients': ['warm',
#      'griddle',
#      'cakes',
#      'taste',
#      'baked',
#      'savory',
#      'sausage',
#      'egg',
#      'melty',
#      'cheese']},
#    {'item': 'Big Breakfast',
#     'price': '',
#     'ingredients': ['buttermilk',
#      'biscuit',
#      'eggs',
#      'savory',
#      'sausage',
#      'hot',
#      'griddle',
#      'crispy']},
#    {'item': 'Big Breakfast with Hotcakes',
#     'price': '',
#     'ingredients': ['buttermilk',
#      'biscuit',
#      'savory',
#      'sausage',
#      'hot',
#      'griddle',
#      'eggs',
#      'crispy',
#      'hotcakes']},
#    {'item': 'Cinnamon Melts', 'price': '', 'ingredients': ['warm']},
#    {'item': 'Hotcakes',
#     'price': '',
#     'ingredients': ['hotcakes', 'margarine', 'flavor']},
#    {'item': 'Hotcakes and Sausage',
#     'price': '',
#     'ingredients': ['hotcakes',
#      'savory',
#      'sausage',
#      'hot',
#      'griddle',
#      'margarine',
#      'flavor']},
#    {'item': 'Bacon&comma Egg & Cheese Bagel',
#     'price': '',
#     'ingredients': ['freshly', 'bagel', 'bacon', 'egg', 'melty', 'cheese']},
#    {'item': 'Southern Style Chicken Biscuit',
#     'price': '',
#     'ingredients': ['buttermilk', 'biscuit', 'meat', 'chicken', 'crispy']},
#    {'item': 'Sausage Burrito',
#     'price': '',
#     'ingredients': ['onions',
#      'eggs',
#      'sausage',
#      'melty',
#      'cheese',
#      'all',
#      'tortilla']},
#    {'item': 'Hash Browns',
#     'price': '',
#     'ingredients': ['Crispy', 'potatoes']}]},
#  {'Name': 'Nosh',
#   'Location': (36.0072372, -78.9471945),
#   'Menu': [{'item': 'Rocket Salad',
#     'price': '$7.39',
#     'ingredients': ['Mesclun',
#      'greens',
#      'parmesan',
#      'croutons',
#      'vinaigrette']},
#    {'item': 'Brown Derby Chopper',
#     'price': '$8.29',
#     'ingredients': ['mesclun',
#      'greens',
#      'cheese',
#      'cheddar',
#      'eggs',
#      'bacon',
#      'tomato',
#      'walnuts',
#      'dressing',
#      'Gluten']},
#    {'item': "Carey's Half and Half",
#     'price': '$7.69',
#     'ingredients': ['soup',
#      'salad',
#      'here',
#      'sandwich',
#      'egg',
#      'salad',
#      'tuna',
#      'salad',
#      'ham',
#      'turkey',
#      'chicken',
#      'salad',
#      'BLT',
#      'spritzer',
#      'veggie',
#      'grilled',
#      'cheese']},
#    {'item': 'Try Nosher Salad',
#     'price': '$8.29',
#     'ingredients': ['tuna',
#      'chicken',
#      'salad',
#      'Egg',
#      'salad',
#      'potato',
#      'salad',
#      'veggie',
#      'slaw',
#      'couscous',
#      'salad']},
#    {'item': "Lancey's Leaves",
#     'price': '$8.29',
#     'ingredients': ['mesclun',
#      'greens',
#      'crunchy',
#      'chicken',
#      'asiago',
#      'cheese',
#      'onions',
#      'dressing']},
#    {'item': 'South of Here',
#     'price': '$7.39',
#     'ingredients': ['cheddar', 'onions', 'tortilla']},
#    {'item': 'The Robinson Burger',
#     'price': '$8.29',
#     'ingredients': ['cheddar',
#      'pepper',
#      'bacon',
#      'lettuce',
#      'tomato',
#      'onion',
#      'mayo',
#      'bun']},
#    {'item': "Wendlyn's Portobello Burger",
#     'price': '$8.29',
#     'ingredients': ['Grilled',
#      'breaded',
#      'portobello',
#      'mushroom',
#      'nosh',
#      'vinaigrette',
#      'onions',
#      'tomato',
#      'mayo',
#      'bun']},
#    {'item': "Uncle Mo's Southwest Turkey",
#     'price': '$8.29',
#     'ingredients': ['Nosh',
#      'turkey',
#      'cheddar',
#      'lettuce',
#      'tomato',
#      'onion',
#      'salsa',
#      'bun']},
#    {'item': "Rascal's Razzamatazz Burger",
#     'price': '$8.29',
#     'ingredients': ['havarti',
#      'lettuce',
#      'onions',
#      'peppers',
#      'tomato',
#      'sauce',
#      'bun']},
#    {'item': 'Peppercorn Burger',
#     'price': '$7.99',
#     'ingredients': ['lettuce', 'tomato', 'onion', 'dressing', 'bun']},
#    {'item': "Mallard's Cardinal Sandwich",
#     'price': '$7.99',
#     'ingredients': ['Grilled',
#      'chicken',
#      'lettuce',
#      'roasted',
#      'pepper',
#      'rustic']},
#    {'item': "Coach's Queso Sandwich",
#     'price': '$7.29',
#     'ingredients': ['Quesadilla',
#      'mozzarella',
#      'cheese',
#      'roasted',
#      'pepper',
#      'onions',
#      'herb',
#      'tortilla',
#      'chicken',
#      'beef']},
#    {'item': 'The Gonzalo Sandwich',
#     'price': '$7.99',
#     'ingredients': ['hummus', 'peppers', 'onions', 'parmesan']},
#    {'item': 'The Deluca Sandwich',
#     'price': '$7.99',
#     'ingredients': ['turkey', 'ham', 'havarti', 'dressing']},
#    {'item': 'Spritzer Sandwich',
#     'price': '$7.99',
#     'ingredients': ['Corned', 'beef', 'sauerkraut', 'dressing', 'rye']},
#    {'item': "Owney's Crunchy Chicken",
#     'price': '$7.99',
#     'ingredients': ['Crunchy',
#      'chicken',
#      'lettuce',
#      'veggie',
#      'slaw',
#      'rustic']},
#    {'item': "Freddie's Egg Salad",
#     'price': '$6.99',
#     'ingredients': ['lettuce', 'tomato', 'rustic', 'wheat']},
#    {'item': "Faye's Turkey",
#     'price': '$7.99',
#     'ingredients': ['turkey',
#      'lettuce',
#      'tomato',
#      'dressing',
#      'rustic',
#      'wheat']},
#    {'item': "Mary Ellen's Chicken Salad",
#     'price': '$7.69',
#     'ingredients': ['chicken',
#      'salad',
#      'lettuce',
#      'dressing',
#      'tomato',
#      'bread']},
#    {'item': "Missy's Tuna Salad",
#     'price': '$7.39',
#     'ingredients': ['Tuna', 'salad', 'greens', 'mayonnaise', 'dill', 'bread']},
#    {'item': "Boo's BLT",
#     'price': '$8.29',
#     'ingredients': ['turkey',
#      'pepper',
#      'bacon',
#      'lettuce',
#      'tomato',
#      'mayonnaise']},
#    {'item': 'Turkey', 'price': '$7.59', 'ingredients': []},
#    {'item': "Kem's Hammer",
#     'price': '$7.59',
#     'ingredients': ['havarti', 'lettuce', 'rye']},
#    {'item': 'Paula Rocks',
#     'price': '$7.99',
#     'ingredients': ['Horseradish',
#      'marinated',
#      'grilled',
#      'chicken',
#      'greens',
#      'dressing',
#      'tomato']},
#    {'item': "Buckster's Beef",
#     'price': '$8.29',
#     'ingredients': ['beef', 'cheddar', 'peppers', 'onions', 'herb']},
#    {'item': 'Chicken Fried Chicken',
#     'price': '$10.99',
#     'ingredients': ['potatoes',
#      'turkey',
#      'sausage',
#      'gravy',
#      'seasonal',
#      'local',
#      'veggies']},
#    {'item': 'BBQ Beef Brisket',
#     'price': '$11.99',
#     'ingredients': ['cake', 'seasonal', 'local', 'veggies']},
#    {'item': 'Milano Pasta',
#     'price': '$8.99',
#     'ingredients': ['pasta',
#      'peppers',
#      'portobello',
#      'mushrooms',
#      'spinach',
#      'tomatoes',
#      'basil',
#      'butter',
#      'sauce',
#      'almonds',
#      'chicken',
#      'shrimp']},
#    {'item': "Freddie's Grilled Flatbread Pizza",
#     'price': '$8.99',
#     'ingredients': ['NOSH',
#      'sauce',
#      'seasonal',
#      'toppings',
#      'feta',
#      'cheese']},
#    {'item': "Katie's Molasses Pork Loin",
#     'price': '$10.99',
#     'ingredients': ['herb', 'quinoa', 'seasonal', 'local', 'veggies']},
#    {'item': 'Crab Stuffed NC Flounder',
#     'price': '$12.99',
#     'ingredients': ['potatoes', 'citrus', 'slaw']},
#    {'item': "Browning's Tomato",
#     'price': '$6.99',
#     'ingredients': ['oil', 'tomato', 'sauce', 'parmesan']},
#    {'item': 'SRP',
#     'price': '$8.29',
#     'ingredients': ['beef',
#      'cheese',
#      'bacon',
#      'cheese',
#      'onions',
#      'mozzarella']},
#    {'item': "P.W.'s Pepperoni",
#     'price': '$7.69',
#     'ingredients': ['Pepperoni',
#      'portobello',
#      'mushrooms',
#      'NOSH',
#      'tomato',
#      'sauce',
#      'mozzarella']},
#    {'item': "Piper's Pick",
#     'price': '$7.69',
#     'ingredients': ['Olive',
#      'oil',
#      'asiago',
#      'cheese',
#      'onions',
#      'mesclun',
#      'greens',
#      'parmesan',
#      'hummus']},
#    {'item': 'Crackers and Dip',
#     'price': '$3.99',
#     'ingredients': ['crackers',
#      'onion',
#      'roasted',
#      'pepper',
#      'hummus',
#      'nuts']},
#    {'item': 'Trio of Dips',
#     'price': '$8.29',
#     'ingredients': ['pepper',
#      'hummus',
#      'onion',
#      'crackers',
#      'NOSH',
#      'kettle',
#      'chips',
#      'nuts']},
#    {'item': 'Crock of Soup',
#     'price': '$3.49',
#     'ingredients': ['homemade',
#      'soups',
#      'meat',
#      'veggie',
#      'NOSH',
#      'crackers']},
#    {'item': 'Chips and Dip',
#     'price': '$3.99',
#     'ingredients': ['kettle',
#      'chips',
#      'onion',
#      'roasted',
#      'pepper',
#      'hummus',
#      'nuts']},
#    {'item': 'PB&J',
#     'price': '$4.99',
#     'ingredients': ['Peanut', 'butter', 'jelly', 'nuts']},
#    {'item': 'Benji Burger',
#     'price': '$4.99',
#     'ingredients': ['burger', 'bun']},
#    {'item': 'Oliver',
#     'price': '$4.99',
#     'ingredients': ['Crunchy',
#      'chicken',
#      'sandwich',
#      'honey',
#      'mustard',
#      'bun']},
#    {'item': "Kev's Turkey",
#     'price': '$4.99',
#     'ingredients': ['lettuce', 'tomato']},
#    {'item': 'The Big Cheese',
#     'price': '$4.99',
#     'ingredients': ['cheese', 'grilled']},
#    {'item': 'Blueberry Cobbler',
#     'price': '$5.29',
#     'ingredients': ['ice', 'blueberries', 'syrup', 'Gluten']},
#    {'item': 'PB & Nanner',
#     'price': '$5.29',
#     'ingredients': ['chocolate', 'ice', 'peanut', 'butter', 'banana', 'nuts']},
#    {'item': 'CYO Shake',
#     'price': '$5.29',
#     'ingredients': ['fruit',
#      'strawberries',
#      'blueberries',
#      'blackberries',
#      'raspberries',
#      'bananas',
#      'ice',
#      'chocolate',
#      'Gluten']},
#    {'item': 'Chocolate Raspberry',
#     'price': '$5.29',
#     'ingredients': ['Chocolate',
#      'ice',
#      'chocolate',
#      'syrup',
#      'raspberries',
#      'Gluten']},
#    {'item': 'Cookies',
#     'price': '$1.59',
#     'ingredients': ['chocolate', 'oatmeal', 'raisin', 'chocolate']},
#    {'item': 'Rich Chocolate Brownie',
#     'price': '$2.69',
#     'ingredients': ['Fudgy',
#      'brownies',
#      'unsweet',
#      'chocolate',
#      'walnuts',
#      'coffee',
#      'nuts']},
#    {'item': 'Cupcakes', 'price': '$1.95', 'ingredients': ['Cupcakes']},
#    {'item': 'Rocket Fuel',
#     'price': '$1.95+',
#     'ingredients': ['NOSH', 'roasted']},
#    {'item': 'Iced Rocket Fuel',
#     'price': '$2.75',
#     'ingredients': ['Chilled', 'NOSH', 'coffee', 'ice']},
#    {'item': 'Red Eye',
#     'price': '$3.25',
#     'ingredients': ['Coffee', 'espresso']},
#    {'item': 'Espresso Double', 'price': '$2.25', 'ingredients': []},
#    {'item': 'Espresso Quadruple', 'price': '$3.25', 'ingredients': []},
#    {'item': 'Cappuccino',
#     'price': '$3.25+',
#     'ingredients': ['steamed', 'milk']},
#    {'item': 'Americano', 'price': '$2.50+', 'ingredients': ['hot', 'water']},
#    {'item': 'Latte', 'price': '$3.25+', 'ingredients': ['steamed', 'milk']},
#    {'item': 'Mocha Latte',
#     'price': '$3.75+',
#     'ingredients': ['steamed', 'milk', 'chocolate', 'syrup']},
#    {'item': 'Cafe au Lait',
#     'price': '$2.75+',
#     'ingredients': ['Coffee', 'steamed', 'milk']},
#    {'item': 'Cafe Mocha',
#     'price': '$3.25+',
#     'ingredients': ['Coffee', 'chocolate', 'syrup', 'steamed', 'milk']},
#    {'item': 'Chai Latte',
#     'price': '$3.50+',
#     'ingredients': ['tea', 'steamed', 'milk']},
#    {'item': 'Perry Wilson',
#     'price': '$5.00',
#     'ingredients': ['Fuel', 'ice', 'chilled', 'hot', 'chocolate']},
#    {'item': 'Hot Chocolate',
#     'price': '$3.00+',
#     'ingredients': ['chocolate', 'steamed', 'milk']},
#    {'item': 'School Bus Breakfast',
#     'price': '$5.29',
#     'ingredients': ['Strawberries', 'banana', 'honey', 'yogurt']},
#    {'item': 'Beaucoup Berries',
#     'price': '$5.29',
#     'ingredients': ['blueberries',
#      'raspberries',
#      'strawberries',
#      'juice',
#      'honey']},
#    {'item': 'Black and Blue',
#     'price': '$5.29',
#     'ingredients': ['blueberries',
#      'banana',
#      'cranberry',
#      'juice',
#      'yogurt',
#      'Gluten']},
#    {'item': 'Fountain of Youth',
#     'price': '$5.29',
#     'ingredients': ['Strawberries',
#      'raspberries',
#      'cranberry',
#      'juice',
#      'yogurt',
#      'Gluten']},
#    {'item': 'In Training',
#     'price': '$5.29',
#     'ingredients': ['Banana',
#      'peanut',
#      'butter',
#      'chocolate',
#      'syrup',
#      'milk',
#      'protein',
#      'Gluten']},
#    {'item': 'Hot Tea',
#     'price': '$2.00',
#     'ingredients': ['Organic',
#      'whole',
#      'teas',
#      'breakfast',
#      'bean',
#      'tropical',
#      'herbal',
#      'nectar',
#      'citrus']},
#    {'item': 'Bottled Water', 'price': '$1.50', 'ingredients': []},
#    {'item': 'Buttermilk Biscuit with Butter and Jelly',
#     'price': '$1.49',
#     'ingredients': ['Biscuit', 'Butter']},
#    {'item': 'Egg Biscuit',
#     'price': '$2.29',
#     'ingredients': ['Egg', 'Biscuit']},
#    {'item': 'Egg and Cheese',
#     'price': '$3.29',
#     'ingredients': ['Egg', 'Cheese']},
#    {'item': 'Egg&comma Cheese&comma Bacon',
#     'price': '$4.29',
#     'ingredients': ['Egg', 'Cheese']},
#    {'item': 'Tomato and Cheese',
#     'price': '$2.99',
#     'ingredients': ['Tomato', 'Cheese']},
#    {'item': 'Crunchy Chicken',
#     'price': '$3.99',
#     'ingredients': ['Crunchy', 'Chicken']},
#    {'item': 'Crunchy Chicken and Cheese',
#     'price': '$4.99',
#     'ingredients': ['Crunchy', 'Chicken', 'Cheese']},
#    {'item': 'Pork Sausage',
#     'price': '$2.99',
#     'ingredients': ['Pork', 'Sausage']},
#    {'item': 'Pork Sausage and Egg',
#     'price': '$3.99',
#     'ingredients': ['Pork', 'Sausage', 'Egg']},
#    {'item': 'Turkey Sausage', 'price': '$3.29', 'ingredients': ['Sausage']},
#    {'item': 'Turkey Sausage and Egg',
#     'price': '$4.29',
#     'ingredients': ['Sausage', 'Egg']},
#    {'item': 'Muffins', 'price': '$1.75', 'ingredients': ['Muffins']},
#    {'item': 'Bagels',
#     'price': '$1.39',
#     'ingredients': ['everything', 'sesame', 'wheat', 'butter', 'jelly']},
#    {'item': 'Bagels with Cheese or Peanut Butter',
#     'price': '$1.89',
#     'ingredients': ['Bagels', 'Cheese', 'Peanut', 'Butter']},
#    {'item': 'Scones', 'price': '$1.75', 'ingredients': ['Scones']},
#    {'item': "Shoaf's Toast",
#     'price': '$6.99',
#     'ingredients': ['toast', 'peanut', 'butter', 'banana', 'honey', 'nuts']},
#    {'item': "Maggie's Scramble",
#     'price': '$6.99',
#     'ingredients': ['eggs',
#      'onions',
#      'peppers',
#      'portobello',
#      'mushrooms',
#      'asiago',
#      'cheese',
#      'warm',
#      'tortilla',
#      'roasted',
#      'pepper',
#      'sauce',
#      'taters',
#      'nuts']},
#    {'item': 'NOSH Buttermilk Flapjacks',
#     'price': '$6.99',
#     'ingredients': ['pancakes']},
#    {'item': "Piper's Patties",
#     'price': '$6.59',
#     'ingredients': ['Savory',
#      'egg',
#      'pancakes',
#      'parsley',
#      'onions',
#      'asiago',
#      'cheese',
#      'bacon',
#      'salsa',
#      'taters']},
#    {'item': "Mike's Breakfast Pizza",
#     'price': '$7.59',
#     'ingredients': ['bacon',
#      'cheddar',
#      'boiled',
#      'egg',
#      'tomato',
#      'NOSH',
#      'sauce',
#      'parmesan']},
#    {'item': "Rocket's Breakfast",
#     'price': '$6.99',
#     'ingredients': ['eggs',
#      'bacon',
#      'sausage',
#      'pork',
#      'turkey',
#      'taters',
#      'fruit',
#      'bagel',
#      'biscuit',
#      'toast']},
#    {'item': "MD's Breakfast",
#     'price': '$6.99',
#     'ingredients': ['yogurt', 'fresh', 'fruit', 'muffin', 'scone', 'toast']}]},
#  {'Name': 'Vin Rouge', 'Location': (36.0106556, -78.9223415), 'Menu': []},
#  {'Name': 'Smashburger',
#   'Location': (36.0091698, -78.9452682),
#   'Menu': [{'item': 'Classic Smash',
#     'price': '',
#     'ingredients': ['cheese',
#      'lettuce',
#      'tomato',
#      'ketchup',
#      'onion',
#      'pickles',
#      'Sauce',
#      'egg',
#      'bun']},
#    {'item': 'Bacon Smash',
#     'price': '',
#     'ingredients': ['bacon', 'cheese', 'lettuce', 'tomato', 'mayo', 'bun']},
#    {'item': 'BBQ Bacon Smash',
#     'price': '',
#     'ingredients': ['BBQ',
#      'sauce',
#      'applewood',
#      'bacon',
#      'cheddar',
#      'onions',
#      'egg',
#      'bun']},
#    {'item': 'Avocado Bacon Club',
#     'price': '',
#     'ingredients': ['Fresh',
#      'avocado',
#      'applewood',
#      'bacon',
#      'lettuce',
#      'tomato',
#      'dressing',
#      'mayo',
#      'bun']},
#    {'item': 'Spicy Baja with Guac',
#     'price': '',
#     'ingredients': ['Fresh',
#      'jalapenos',
#      'guacamole',
#      'pepper',
#      'lettuce',
#      'tomato',
#      'onion',
#      'mayo',
#      'spicy',
#      'bun']},
#    {'item': 'Truffle Mushroom Swiss',
#     'price': '',
#     'ingredients': ['mayo', 'crimini', 'mushrooms', 'egg', 'bun']},
#    {'item': 'French Fries', 'price': '', 'ingredients': ['Fries']},
#    {'item': 'Smashfries',
#     'price': '',
#     'ingredients': ['olive', 'oil', 'garlic']},
#    {'item': 'Sweet Potato Fries',
#     'price': '',
#     'ingredients': ['Potato', 'Fries']},
#    {'item': 'Sweet Potato Smashfries',
#     'price': '',
#     'ingredients': ['Potato', 'Smashfries']},
#    {'item': 'Haystack Onions', 'price': '', 'ingredients': ['Sauce']},
#    {'item': 'Side Salad with Dressing', 'price': '', 'ingredients': ['Salad']},
#    {'item': 'Kids Hamburger Meal',
#     'price': '',
#     'ingredients': ['Kids', 'Hamburger', 'Meal']},
#    {'item': 'Kids Cheeseburger Meal',
#     'price': '',
#     'ingredients': ['Kids', 'Cheeseburger', 'Meal']},
#    {'item': 'Crispy Chicken Strips Meal',
#     'price': '',
#     'ingredients': ['Crispy', 'Chicken', 'Meal']},
#    {'item': 'Classic Cobb',
#     'price': '',
#     'ingredients': ['Fresh',
#      'greens',
#      'cheese',
#      'cheddar',
#      'fried',
#      'egg',
#      'applewood',
#      'bacon',
#      'tomatoes',
#      'onions',
#      'buttermilk',
#      'dressing']},
#    {'item': 'BBQ Ranch Salad',
#     'price': '',
#     'ingredients': ['Fresh',
#      'greens',
#      'cheddar',
#      'applewood',
#      'bacon',
#      'tomatoes',
#      'onions',
#      'dressing',
#      'BBQ',
#      'sauce']},
#    {'item': 'Fountain Drinks', 'price': '', 'ingredients': ['Drinks']},
#    {'item': 'Iced Tea', 'price': '', 'ingredients': ['Tea']},
#    {'item': 'Beer Varieties', 'price': '', 'ingredients': ['Beer']},
#    {'item': 'Chocolate', 'price': '', 'ingredients': ['Chocolate']},
#    {'item': 'Vanilla', 'price': '', 'ingredients': []},
#    {'item': 'Strawberry', 'price': '', 'ingredients': []},
#    {'item': 'Oreo', 'price': '', 'ingredients': ['Oreo']},
#    {'item': 'Chocolate Oreo',
#     'price': '',
#     'ingredients': ['Chocolate', 'Oreo']},
#    {'item': 'Peanut Butter', 'price': '', 'ingredients': ['Peanut', 'Butter']},
#    {'item': 'Salted Caramel', 'price': '', 'ingredients': ['Salted']}]}]

# %%
# Out:
# {'cal': 4, 'sugars': -3, 'totfat': -3, 'unsatfat': -6, 'satfat': -3, 'transfat': -3, 'carbs': 6, 'protein': 6, 'fiber': -9, 'sod': 3, 'mag': -6, 'totfolate': -6, 'potass': -6, 'vd': -6}
# -8

# %%
def weight(recDict):
    switcher = {
    'cal': (2,3),
    'sugars': (1,3),
    'totfat': (1,3),
    'unsatfat': (2,2),
    'satfat': (1,3),
    'transfat': (1,3),
    'carbs': (2,3),
    'protein': (2,3),
    'fiber': (3,1),
    'sod': (1,3),
    'mag': (2,1),
    'totfolate': (2,1),
    'potass': (2,1),
    'vd': (2,1),
    }
    weight_adequacy = {} #{'nutrient': weight_value, etc}
    weight_moderation = {}
    for nutrient in recDict:
        weight_adequacy[nutrient], weight_moderation[nutrient] = switcher[nutrient]
    return weight_adequacy, weight_moderation

# switch for weights

# %%
def single_dictionary(menu_item):
    ingredients_list = menu_item['ingredients']
    #create new dict
    menu_item['nutrition'] = {}
    for ingredient in ingredients_list:
        try:
            menu_item['nutrition'][ingredient] = nutri_search(ingredient)
        except:
            print(nutri_search(ingredient))
            continue
    return menu_item

def nutrientScore(nutrition_info, recommended_dict_i):
    recDict = recommended_dict_i
    nutrient_sum_dict={'cal':0,'sugars':0,'totfat':0,'unsatfat':0,'satfat':0,'transfat':0,'carbs':0,'protein':0,'fiber':0,'sod':0,'mag':0,'totfolate':0,'potass':0,'vd':0}
    nutrient_fracs={}
    for ingredient_key in nutrition_info:
        nutrition_dict_for_ingredient = nutrition_info[ingredient_key]
        for nutrient in nutrition_dict_for_ingredient:            
            ingredient_nutrient_value = nutrition_dict_for_ingredient[nutrient]
            nutrient_sum_dict[nutrient] = nutrient_sum_dict[nutrient]+ingredient_nutrient_value
    
    for nutrient in nutrient_sum_dict:
        goal = recDict[nutrient]
        actual = nutrient_sum_dict[nutrient]
        frac = actual/goal
        nutrient_fracs[nutrient] = frac
    
    # select weights for each adequacy and moderation for each nutrient
    weight_adequacy, weight_moderation = weight(recDict)
    
    # Scoring
    nutrient_scores_adequacy= {}
    nutrient_scores_moderation = {}
    for nutrient in nutrient_fracs:
        if nutrient_fracs[nutrient] >= 2 :       
            nutrient_scores_adequacy[nutrient] = 3* weight_adequacy[nutrient]
            nutrient_scores_moderation[nutrient] = -3* weight_moderation[nutrient]
        if nutrient_fracs[nutrient] >= 1.25 and nutrient_fracs[nutrient] <2: 
            nutrient_scores_adequacy[nutrient] = 2* weight_adequacy[nutrient]
            nutrient_scores_moderation[nutrient] = -2* weight_moderation[nutrient]
        if nutrient_fracs[nutrient] >= 1 and nutrient_fracs[nutrient] <1.25: 
            nutrient_scores_adequacy[nutrient] = 1* weight_adequacy[nutrient]
            nutrient_scores_moderation[nutrient] = -1* weight_moderation[nutrient]
        if nutrient_fracs[nutrient] >= .75 and nutrient_fracs[nutrient] <1: 
            nutrient_scores_adequacy[nutrient] = -1* weight_adequacy[nutrient]
            nutrient_scores_moderation[nutrient] = 1* weight_moderation[nutrient]
        if nutrient_fracs[nutrient] >= .5 and nutrient_fracs[nutrient] <.75: 
            nutrient_scores_adequacy[nutrient] = -2* weight_adequacy[nutrient]
            nutrient_scores_moderation[nutrient] = 2* weight_moderation[nutrient]
        if nutrient_fracs[nutrient] >= 0 and nutrient_fracs[nutrient] <.5: 
            nutrient_scores_adequacy[nutrient] = -3* weight_adequacy[nutrient]
            nutrient_scores_moderation[nutrient] = 3* weight_moderation[nutrient]
    adequacy = sum(nutrient_scores_adequacy.values())
    moderation = sum(nutrient_scores_moderation.values())
    score = adequacy + moderation # a more positive score is better
            
    return score

# %%
from usda.client import UsdaClient
client = UsdaClient("qKef3l8Q2NCw3laIuhWZ9Sijr2NhevBARWxHXhBY")

def nutri_search(ingredient): 
    #find ID number
    foods_search = client.search_foods('{}'.format(ingredient), 1)
    food = next(foods_search)
    
    report = client.get_food_report(food.id)
    
    names = []
    ids = []
    values = []
    for nutrient in report.nutrients: 
        names.append(nutrient.name)
        ids.append(nutrient.id)
        values.append(nutrient.value)
        
    nutrition_dict = dict(zip(names,values))
    
    try:
        cal = nutrition_dict['Energy']
    except:
        cal = 0
    try:
        sugars = nutrition_dict['Sugars, total']
    except:
        sugars = 0
    try:
        totfat = nutrition_dict['Total lipid (fat)']
    except: 
        totfat = 0
    try:
        unsatfat = nutrition_dict['Fatty acids, total polyunsaturated']
    except: 
        unsatfat = 0
    try:
        satfat = nutrition_dict['Fatty acids, total saturated']
    except: 
        satfat = 0
    try:
        transfat = nutrition_dict['Fatty acids, total trans']
    except: 
        transfat = 0
    try:
        carbs = nutrition_dict['Carbohydrate, by difference']
    except: 
        carbs = 0
    try:
        protein = nutrition_dict['Protein']
    except: 
        protein = 0
    try:
        fiber = nutrition_dict['Fiber, total dietary']
    except: 
        fiber = 0
    try:
        sod = nutrition_dict['Sodium, Na']
    except:
        sod = 0
    try:
        mag = nutrition_dict['Magnesium, Mg']
    except: 
        mag = 0
    try:
        folate = nutrition_dict['Folate, DFE']
    except: 
        folate = 0
    try:
        potass = nutrition_dict['Potassium, K']
    except: 
        potass = 0
    try:
        vd = nutrition_dict['Vitamin D']
    except: 
        vd = 0
    
    nutri_dict={'cal':cal,'sugars':sugars,'totfat':totfat,'unsatfat':unsatfat,'satfat':satfat,'transfat':transfat,'carbs':carbs,'protein':protein,'fiber':fiber,'sod':sod,'mag':mag,'totfolate':folate,'potass':potass,'vd':vd}
    
    return nutri_dict

# %%
def create_list_rest_dictionaries(data):
    for r in range(len(data)): # for every restaurant dictionary in data
        menu = data[r]['Menu'] # outputs a list of menu item dictionaries
        for j in range(len(menu)):
            menu_item=menu[j]
            menu_item['nutrition']={} # add 'nutrition' dictionary for each menu_item
            ingredients_list = menu_item['ingredients']
            for i in range(len(ingredients_list)):
                try:
                    dict_nutri_values = nutri_search(ingredients_list[i])            
                    nutrition_dict = menu_item['nutrition']
                    nutrition_dict[ingredients_list[i]] = dict_nutri_values
                except: 
                    continue
    return data

# this generates the correct dictionary depending on gender and activity

def recommended_dict(gender, activity, age):
    if gender == 0:
        if activity == 0:
            if  age >=16 and age <=18:
                cals = 2400;percent_totfat = .3;protein = 52;fiber = 30.8
            elif age >=19 and age <=20:
                cals = 2600;percent_totfat = .275;protein = 56;fiber = 33.6
            elif age >=21 and age <=30:
                cals = 2400;percent_totfat = .275;protein = 56;fiber = 33.6
            elif  age >=31 and age <=40:
                cals = 2400;protein = 56;percent_totfat = .275;fiber = 30.8
            elif  age >=41 and age <=50:
                cals = 2200;percent_totfat = .275;protein = 56;fiber = 30.8
            elif  age >=51 and age <=60:
                cals = 2200;percent_totfat = .275;protein = 56;fiber = 28
            elif  age >=61:
                cals = 2000;percent_totfat = .275;protein = 56;fiber = 28
        elif activity == 1:
            if  age >=16 and age <=25:
                cals = 2800;percent_totfat = .3;protein = 52
                if age >=16 and age <= 18:
                    fiber = 30.8
                elif age >=19 and age <= 25:
                    fiber = 33.6
            elif age >=26 and age <=45:
                cals = 2600;percent_totfat = .275;protein = 56
                if age >= 26 and age <=30:
                    fiber = 33.6
                elif age >= 31 and age <= 45:
                    fiber = 30.8
            elif age >=46 and age <= 65:
                cals = 2400;percent_totfat = .275;protein = 56
                if age >= 46 and age <= 50:
                    fiber = 30.8
                elif age >=51:
                    fiber = 28
            elif age >=66:
                cals = 2200;percent_totfat = .275;protein = 56
        elif activity == 2:        
            if  age >=16 and age <=18:
                cals = 3200;percent_totfat = .3;protein = 52;fiber = 30.8
            elif  age >=19 and age <=35:
                cals = 3000;percent_totfat = .275;protein = 56
                if age >= 19 and age <= 30:
                    fiber = 33.6
                elif age >= 31 and age >= 35:
                    fiber = 30.8
            elif  age >=36 and age <=55:
                cals = 2800;percent_totfat = .275;protein = 56
                if age >= 36 and age <= 50:
                    fiber = 30.8
                elif age >=51 and age <= 55:
                    fiber = 28
            elif  age >=56 and age <=75:
                cals = 2600;percent_totfat = .275;protein = 56;fiber = 28
            elif age >= 76:
                cals = 2400;percent_totfat = .275;protein = 56;fiber = 28
                
        recommended_dict = {'cal':cals/3,'sugars':.09*cals/3,'totfat': percent_totfat*cals/3,'unsattfat':.6*percent_totfat*cals/3,'satfat':.09*cals/3,'transfat':.01*cals/3,'carbs':130/3,'protein':56/3,'fiber':fiber/3,'sod':2300/3,'mag':420/3,'totfolate':400/3,'potass':4700/3,'vd':600/3}
        
    elif gender == 1:
        if activity == 0:
            if age >=16 and age <=18:
                cals = 1800;percent_totfat = .3;fiber = 25.2
            elif  age >=19 and age <=25:
                cals = 2000;percent_totfat = .275;fiber = 28
            elif  age >=26 and age <=50:
                cals = 1800;percent_totfat = .275
                if age >= 26 and age <=30:
                    fiber = 28
                elif age >30 and age <=50:
                    fiber = 25.2
            elif  age >=51:
                cals = 1600;percent_totfat = .275;fiber = 22.4
        elif activity == 1:
            if age >=16 and age <=18:
                cals = 2000;percent_totfat = .3;fiber = 25.2                
            elif  age >=19 and age <=25:
                cals = 2500;percent_totfat = .275;fiber = 28
            elif  age >=26 and age <=50:
                cals = 2000;percent_totfat = .275
                if age >= 26 and age <=30:
                    fiber = 28
                elif age >30 and age <=50:
                    fiber = 25.2
            elif  age >=51:
                cals = 1800;percent_totfat = .275;fiber = 22.4
        elif activity == 2:
            if age >=16 and age <=30:
                cals = 2400;percent_totfat = .275
                if age >=16 and age <=18:
                    fiber = 25.2
                elif age >18 and age <=25:
                    fiber = 28
                elif age >= 26 and age <=30:
                    fiber = 28
            elif age >30 and age <=60:
                cals = 2200;percent_totfat = .275
                if age >30 and age <=50:
                    fiber = 25.2
                elif age> 50:
                    fiber = 22.4
            elif age>60:
                cals = 2000;percent_totfat = .275;fiber = 22.4
                
        recommended_dict = {'cal':cals/3,'sugars':.09*cals/3,'totfat': percent_totfat*cals/3,'unsatfat':.6*percent_totfat*cals/3,'satfat':.09*cals/3,'transfat':.01*cals/3,'carbs':130/3,'protein':46/3,'fiber':fiber/3,'sod':2300/3,'mag':320/3,'totfolate':400/3,'potass':4700/3,'vd':600/3}
        
    return recommended_dict
